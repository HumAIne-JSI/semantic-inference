# %%
import json

import aas_core3.jsonization as aas_jsonization

text = """\
    {
    "assetAdministrationShells": [
  {
    "idShort": "Productionsinsel_KUBA",
    "id": "I1",
    "assetInformation": {
      "assetKind": "Instance",
      "assetType": "Factory"
    },
    "submodels": [
      {
        "type": "ModelReference",
        "keys": [
          {
            "type": "Submodel",
            "value": "https://smartfactory.de/ids/sm/9055_8060_1032_3721"
          }
        ]
      },
      {
        "type": "ModelReference",
        "keys": [
          {
            "type": "Submodel",
            "value": "https://example.com/ids/sm/6531_9082_3022_4755"
          }
        ]
      }
    ],
    "modelType": "AssetAdministrationShell"
  }
],
    "conceptDescriptions": [],
    "submodels": [
  {
    "idShort": "Nameplate",
    "id": "https://smartfactory.de/ids/sm/9055_8060_1032_3721",
    "semanticId": {
      "type": "ExternalReference",
      "keys": [
        {
          "type": "Submodel",
          "value": "https://admin-shell.io/zvei/nameplate/1/0/Nameplate"
        }
      ]
    },
    "submodelElements": [
      {
        "idShort": "Address",
        "semanticId": {
          "type": "ExternalReference",
          "keys": [
            {
              "type": "ConceptDescription",
              "value": "0173-1#02-AAQ832#005"
            }
          ]
        },
        "value": [
          {
            "idShort": "Phone01",
            "semanticId": {
              "type": "ExternalReference",
              "keys": [
                {
                  "type": "ConceptDescription",
                  "value": "0173-1#02-AAQ833#005"
                }
              ]
            },
            "value": [
              {
                "idShort": "TypeOfTelephone",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": [
                    {
                      "type": "ConceptDescription",
                      "value": "0173-1#02-AAO137#003"
                    }
                  ]
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "Email01",
            "semanticId": {
              "type": "ExternalReference",
              "keys": [
                {
                  "type": "ConceptDescription",
                  "value": "0173-1#02-AAQ836#005"
                }
              ]
            },
            "value": [
              {
                "idShort": "EmailAddress",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": [
                    {
                      "type": "ConceptDescription",
                      "value": "0173-1#02-AAO198#002"
                    }
                  ]
                },
                "valueType": "xs:string",
                "value": "info@smartfactory.de",
                "modelType": "Property"
              },
              {
                "idShort": "TypeOfEmailAddress",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": [
                    {
                      "type": "ConceptDescription",
                      "value": "0173-1#02-AAO199#003"
                    }
                  ]
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          }
        ],
        "modelType": "SubmodelElementCollection"
      },
      {
        "idShort": "YearOfConstruction",
        "semanticId": {
          "type": "ExternalReference",
          "keys": [
            {
              "type": "ConceptDescription",
              "value": "0173-1#02-AAP906#001"
            }
          ]
        },
        "valueType": "xs:integer",
        "value": "2023",
        "modelType": "Property"
      }
    ],
    "modelType": "Submodel"
  },
  {
    "idShort": "AssuredServices",
    "id": "https://example.com/ids/sm/6531_9082_3022_4755",
    "semanticId": {
      "type": "ExternalReference",
      "keys": [
        {
          "type": "Submodel",
          "value": "https://smartfactory.de/aas/submodel/AssuredServices#1/0"
        }
      ]
    },
    "submodelElements": [
      {
        "idShort": "ServiceOffering01",
        "semanticId": {
          "type": "ExternalReference",
          "keys": [
            {
              "type": "GlobalReference",
              "value": "0173-1#01-AAB315#008"
            }
          ]
        },
        "value": [
          {
            "idShort": "ServiceName",
            "semanticId": {
              "type": "ExternalReference",
              "keys": [
                {
                  "type": "GlobalReference",
                  "value": "0173-1#01-ADT425#011"
                }
              ]
            },
            "valueType": "xs:string",
            "value": "3DPrintingService",
            "modelType": "Property"
          },
          {
            "idShort": "GeneralConditions",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Material",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "PLA",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "value": [
                      {
                        "idShort": "PolyMax_RED",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "PolyMax_BLUE",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "PolyMax_WHITE",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "PrusamentPLA_Lipstick_RED",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "PrusamentPLA_Galaxy_BLACK",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "PrusamentPLA_Galaxy_SILVER",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      }
                    ],
                    "modelType": "SubmodelElementCollection"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "SizeOfProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MaxLength",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": [
                        {
                          "type": "ConceptDescription",
                          "value": "https://example.com/ids/cd/8431_9012_2122_9362"
                        }
                      ]
                    },
                    "valueType": "xs:integer",
                    "value": "21",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "MaxWidth",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": [
                        {
                          "type": "ConceptDescription",
                          "value": "https://example.com/ids/cd/8431_9012_2122_9362"
                        }
                      ]
                    },
                    "valueType": "xs:integer",
                    "value": "25",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "MaxHeight",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": [
                        {
                          "type": "ConceptDescription",
                          "value": "https://example.com/ids/cd/8431_9012_2122_9362"
                        }
                      ]
                    },
                    "valueType": "xs:integer",
                    "value": "21",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "WeightOfProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MaxWeight",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": [
                        {
                          "type": "ConceptDescription",
                          "value": "https://example.com/ids/cd/1212_2170_2032_8161"
                        }
                      ]
                    },
                    "valueType": "xs:double",
                    "value": "0.5",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "InputFactors",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "CAD",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "TechnicalDrawing",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "AASofProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "SelectableProcessOptimization",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "FastestProductionTime",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "LowestEnergyConsumption",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "LowestCost",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "HighestQuality",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "QualitativeData",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "DecisionBasedOnInputFactors",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "Standards",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "ISO9001",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "IATF16949",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "VDI3405",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "Quantity",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "TermsOfDeliveryAndPayment",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Price",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "According to offer",
                "modelType": "Property"
              },
              {
                "idShort": "PaymentTerms",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "IncoTerms",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "OtherAgreements",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "CapabilityReferences",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "FusedLayerModelling",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": {
                  "type": "ModelReference",
                  "keys": [
                    {
                      "type": "GlobalReference",
                      "value": "VDI _3405_Additive Fertigungsverfahren"
                    }
                  ]
                },
                "modelType": "ReferenceElement"
              }
            ],
            "modelType": "SubmodelElementCollection"
          }
        ],
        "modelType": "SubmodelElementCollection"
      },
      {
        "idShort": "ServiceOffering02",
        "semanticId": {
          "type": "ExternalReference",
          "keys": [
            {
              "type": "GlobalReference",
              "value": "0173-1#01-AAB315#008"
            }
          ]
        },
        "value": [
          {
            "idShort": "ServiceName",
            "semanticId": {
              "type": "ExternalReference",
              "keys": [
                {
                  "type": "GlobalReference",
                  "value": "0173-1#01-BAC063#008"
                }
              ]
            },
            "valueType": "xs:string",
            "value": "AssemblyService",
            "modelType": "Property"
          },
          {
            "idShort": "GeneralConditions",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Material",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "InorganicMetallicMaterials",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "InorganicNonMetallicMaterials",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "OrganicNonMetallicMaterials",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "SizeOfProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "WeightOfProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MaxWeight",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": [
                        {
                          "type": "ConceptDescription",
                          "value": "https://example.com/ids/cd/1212_2170_2032_8161"
                        }
                      ]
                    },
                    "valueType": "xs:integer",
                    "value": "20",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "InputFactors",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "CAD",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "TechnicalDrawing",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "AASofProduct",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "SelectableProcessOptimization",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "LowestCost",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "LocalConformity",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "QualitativeData",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "DecisionBasedOnInputFactors",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "Standards",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "ISO9001",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "IATF16949",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "Quantity",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "TermsOfDeliveryAndPayment",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Price",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "According to offer",
                "modelType": "Property"
              },
              {
                "idShort": "PaymentTerms",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "IncoTerms",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "OtherAgreements",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "CapabilityReferences",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "PickAndPlace",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "ReferenceElement"
              },
              {
                "idShort": "Transport",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "ReferenceElement"
              },
              {
                "idShort": "FullAutomatedAssembly",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "ReferenceElement"
              },
              {
                "idShort": "PartAutomatedAssembly",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "ReferenceElement"
              },
              {
                "idShort": "ManualAssembly",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "ReferenceElement"
              }
            ],
            "modelType": "SubmodelElementCollection"
          }
        ],
        "modelType": "SubmodelElementCollection"
      },
      {
        "idShort": "ServiceOffering03",
        "semanticId": {
          "type": "ExternalReference",
          "keys": [
            {
              "type": "GlobalReference",
              "value": "0173-1#01-AAB315#008"
            }
          ]
        },
        "value": [
          {
            "idShort": "ServiceName",
            "semanticId": {
              "type": "ExternalReference",
              "keys": [
                {
                  "type": "GlobalReference",
                  "value": "0173-1#01-AKG759#018"
                }
              ]
            },
            "valueType": "xs:string",
            "value": "QualityControl",
            "modelType": "Property"
          },
          {
            "idShort": "GeneralConditions",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "DescriptionOfService",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "Hardware",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "CPU",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "GPU",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "Software",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MachineLearning",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "DeepLearning",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "value": [
                      {
                        "idShort": "CNN",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "GANS",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "Transformers",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "RNN",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "YOLO",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      },
                      {
                        "idShort": "SSD",
                        "semanticId": {
                          "type": "ExternalReference",
                          "keys": []
                        },
                        "valueType": "xs:string",
                        "value": "",
                        "modelType": "Property"
                      }
                    ],
                    "modelType": "SubmodelElementCollection"
                  },
                  {
                    "idShort": "FederatedLearning",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "InputData",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "VisionData",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "SensorData",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "ColorSpace",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "MinimumResolution",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "ModelWeights",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "OutputData",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "DataLabels",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "Classes",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "Performance",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "AveragePrecision",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "HardwareRequirements",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "On_Premises_Software",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MinRAM",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "MinCPU",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "OperatingSystem",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              },
              {
                "idShort": "Cloud_Software",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": [
                  {
                    "idShort": "MinRAM",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "MinCPU",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  },
                  {
                    "idShort": "OperatingSystem",
                    "semanticId": {
                      "type": "ExternalReference",
                      "keys": []
                    },
                    "valueType": "xs:string",
                    "value": "",
                    "modelType": "Property"
                  }
                ],
                "modelType": "SubmodelElementCollection"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "TermsOfDeliveryAndPayment",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Price",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "According to offer",
                "modelType": "Property"
              },
              {
                "idShort": "PaymentTerms",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "Limitations",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "Lighting",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "CameraPosition",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "ObjectSize",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "Blur",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "ImageResolution",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "ObjectType",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              },
              {
                "idShort": "TimeDuration",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "valueType": "xs:string",
                "value": "",
                "modelType": "Property"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "CapabilityReferences",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "value": [
              {
                "idShort": "ObjectDetection",
                "semanticId": {
                  "type": "ExternalReference",
                  "keys": []
                },
                "value": {
                  "type": "ModelReference",
                  "keys": [
                    {
                      "type": "AssetAdministrationShell",
                      "value": "P3"
                    },
                    {
                      "type": "Submodel",
                      "value": "Cap"
                    },
                    {
                      "type": "SubmodelElementCollection",
                      "value": "QC"
                    }
                  ]
                },
                "modelType": "ReferenceElement"
              }
            ],
            "modelType": "SubmodelElementCollection"
          },
          {
            "idShort": "ConditionsOfUse",
            "semanticId": {
              "type": "ExternalReference",
              "keys": []
            },
            "modelType": "SubmodelElementCollection"
          }
        ],
        "modelType": "SubmodelElementCollection"
      }
    ],
    "modelType": "Submodel"
  }
]
}"""

jsonable = json.loads(text)

environment = aas_jsonization.environment_from_jsonable(
    jsonable
)

# for something in environment.descend():
#     print(type(something))

jsonable2 = aas_jsonization.to_jsonable(environment)
print(json.dumps(jsonable2, indent=2))
# Out:
# {
#   "assetAdministrationShells": [
#     {
#       "idShort": "Productionsinsel_KUBA",
#       "id": "I1",
#       "assetInformation": {
#         "assetKind": "Instance",
#         "assetType": "Factory"
#       },
#       "submodels": [
#         {
#           "type": "ModelReference",
#           "keys": [
#             {
#               "type": "Submodel",
#               "value": "https://smartfactory.de/ids/sm/9055_8060_1032_3721"
#             }
#           ]
#         },
#         {
#           "type": "ModelReference",
#           "keys": [
#             {
#               "type": "Submodel",
#               "value": "https://example.com/ids/sm/6531_9082_3022_4755"
#             }
#           ]
#         }
#       ],
#       "modelType": "AssetAdministrationShell"
#     }
#   ],
#   "submodels": [
#     {
#       "idShort": "Nameplate",
#       "id": "https://smartfactory.de/ids/sm/9055_8060_1032_3721",
#       "semanticId": {
#         "type": "ExternalReference",
# ...

# %%
import aas_core3.types as aas_types
import json

import aas_core3.jsonization as aas_jsonization

# Create the first element
some_element = aas_types.Property(
    id_short="some_property",
    value_type=aas_types.DataTypeDefXSD.INT,
    value="1984"
)

# Create the second element
another_element = aas_types.Blob(
    id_short="some_blob",
    content_type="application/octet-stream",
    value=b'\xDE\xAD\xBE\xEF'
)

# You can directly access the element properties.
another_element.value = b'\xDE\xAD\xC0\xDE'

# Nest the elements in a submodel
submodel = aas_types.Submodel(
    id="some-unique-global-identifier",
    submodel_elements=[
        some_element,
        another_element
    ]
)

# Now create the environment to wrap it all up
environment = aas_types.Environment(
    submodels=[submodel]
)

# You can access the properties from the children as well.
environment.submodels[0].submodel_elements[1].value = b'\xC0\x01\xCA\xFE'

    


print(json.dumps(aas_jsonization.to_jsonable(environment), indent=2))

# Now you can do something with the environment...
# Out:
# {
#   "submodels": [
#     {
#       "id": "some-unique-global-identifier",
#       "submodelElements": [
#         {
#           "idShort": "some_property",
#           "valueType": "xs:int",
#           "value": "1984",
#           "modelType": "Property"
#         },
#         {
#           "idShort": "some_blob",
#           "value": "wAHK/g==",
#           "contentType": "application/octet-stream",
#           "modelType": "Blob"
#         }
#       ],
#       "modelType": "Submodel"
#     }
#   ]
# }

# %%
import random
import string

import aas_core3.types as aas_types
import json

import aas_core3.jsonization as aas_jsonization
import aas_core3.constants as aas_constants

from enum import Enum

# Define an enumeration class
class MachineType(Enum):
    DRILLER = "Driller"
    CIRCLE_DRAWER = 2
    BLUE = 3


def generate_random_string(size=10):
    # Define the characters you want to include in the random string
    characters = string.ascii_letters + string.digits  # you can customize this based on your requirements
    
    # Generate the random string
    random_string = ''.join(random.choice(characters) for _ in range(size))
    
    return random_string


aass = []
submodels = []
# concept_descriptions = []
# for i in range(1000):
#     aas_id = generate_random_string()
#     aas_info = aas_types.AssetInformation(asset_kind=aas_types.AssetKind.INSTANCE)
#     typ = random.choice(list(MachineType))
#     if typ == MachineType.DRILLER:
#         aas_types.AssetInformation(asset_kind=aas_types.AssetKind.INSTANCE)
#         aas_types.AssetAdministrationShell(id: generate_random_string())
#         submodel = aas_types.Submodel(
#             id=generate_random_string(),
#             submodel_elements=[
#                 some_element,
#                 another_element
#             ]
#         )
#         print(aas_id, typ.value)


aass = []

drill_names = [
    "QuantumPro X1",
    "EcoDrive Elite",
    "TitanCraft Pro-1",
    "SwiftDrill Precision",
    "SolarSprint 2000",
    "MegaForce Turbo",
    "GreenHarmony EcoPro",
]

drill_manufacturers = [
    "QuantumTech Industries",
    "EnviroTech Drills",
    "TitanCraft Engineering",
    "QuantumTech Industries",
    "EnviroTech Drills",
    "TitanCraft Engineering",
    "EnviroTech Drills",
]

drill_descriptions = [
    "The QuantumPro X1 is a precision drilling marvel designed for woodworking enthusiasts. With its advanced gyroscopic stabilization technology and variable speed control, this driller ensures unparalleled accuracy and ease of use. Its sleek design and ergonomic grip make it a favorite among DIYers and professionals alike.",
    "The EcoDrive Elite is a sustainable drilling solution for eco-conscious users. Powered by a cutting-edge solar-charged battery, this driller combines efficiency with environmental responsibility. Ideal for various materials, the EcoDrive Elite is perfect for those who prioritize both performance and sustainability in their projects.",
    "The TitanCraft Pro-1 is a rugged and robust driller built for heavy-duty tasks. With its high torque motor and durable metal construction, this powerhouse excels in drilling through tough materials such as metal and masonry. The TitanCraft Pro-1 is a reliable choice for professionals requiring strength and endurance in their drilling endeavors.",
    "The SwiftDrill Precision is a compact and lightweight driller designed for fine detailing and intricate work. Its precise control and minimal vibration ensure a steady hand for delicate tasks. DIY hobbyists and artisans appreciate the SwiftDrill Precision for its ease of maneuverability and exceptional accuracy.",
    "The SolarSprint 2000 is a state-of-the-art solar-powered driller that combines efficiency with environmental sustainability. Perfect for light to medium-duty tasks, this driller's innovative energy source provides users with a reliable and eco-friendly option for their drilling needs.",
    "The MegaForce Turbo is a high-performance driller engineered for speed and power. With its turbocharged motor and advanced cooling system, this driller excels in quick and efficient drilling tasks. The MegaForce Turbo is the go-to choice for professionals who demand rapid results without compromising on durability.",
    "The GreenHarmony EcoPro is a revolutionary driller that sets new standards in sustainability and performance. Powered by a combination of solar energy and recycled materials, this environmentally conscious driller is ideal for users who prioritize green technology without compromising on power. The GreenHarmony EcoPro is the perfect blend of eco-friendliness and top-notch drilling capabilities, making it a standout choice for the conscientious DIY enthusiast.",
]



circle_cutter_names = [
    "CirclerPro X2",
    "EcoRound Precision",
    "TitanCut CircleMaster",
    "SwiftCircle Elite",
    "SolarSphere 3000",
    "MegaRound Turbo",
    "GreenCirc HarmonyPro",
]

circle_cutter_manufacturers = [
    "QuantumTech Industries",
    "EnviroTech Cutters",
    "TitanCraft Engineering",
    "QuantumTech Industries",
    "EnviroTech Cutters",
    "TitanCraft Engineering",
    "EnviroTech Cutters",
]

circle_cutter_descriptions = [
    "The CirclerPro X2 is a precision circle cutting machine designed for woodworking enthusiasts. With advanced features and adjustable parameters, this circle cutter ensures precise and smooth cuts. Its ergonomic design and user-friendly interface make it a favorite among DIYers and professionals alike.",
    "The EcoRound Precision is a sustainable circle cutting solution for eco-conscious users. Powered by a cutting-edge solar-charged battery, this circle cutter combines efficiency with environmental responsibility. Ideal for various materials, the EcoRound Precision is perfect for those who prioritize both performance and sustainability in their projects.",
    "The TitanCut CircleMaster is a rugged and versatile circle cutting machine built for heavy-duty tasks. With its high cutting speed and durable construction, this powerhouse excels in cutting through various materials. The TitanCut CircleMaster is a reliable choice for professionals requiring strength and precision in their circle cutting endeavors.",
    "The SwiftCircle Elite is a compact and lightweight circle cutter designed for fine detailing and intricate work. Its precise control and minimal vibration ensure a steady hand for delicate tasks. DIY hobbyists and artisans appreciate the SwiftCircle Elite for its ease of maneuverability and exceptional accuracy.",
    "The SolarSphere 3000 is a state-of-the-art solar-powered circle cutting machine that combines efficiency with environmental sustainability. Perfect for light to medium-duty tasks, this circle cutter's innovative energy source provides users with a reliable and eco-friendly option for their cutting needs.",
    "The MegaRound Turbo is a high-performance circle cutting machine engineered for speed and power. With its turbocharged cutting mechanism and advanced cooling system, this circle cutter excels in quick and efficient cutting tasks. The MegaRound Turbo is the go-to choice for professionals who demand rapid results without compromising on durability.",
    "The GreenCirc HarmonyPro is a revolutionary circle cutting machine that sets new standards in sustainability and performance. Powered by a combination of solar energy and recycled materials, this environmentally conscious circle cutter is ideal for users who prioritize green technology without compromising on cutting precision. The GreenCirc HarmonyPro is the perfect blend of eco-friendliness and top-notch circle cutting capabilities, making it a standout choice for the conscientious DIY enthusiast.",
]

# Circular Saws
circular_saw_names = [
    "CircuMax Pro-3000",
    "EcoBlade Elite",
    "TitanSaw Master-2",
    "SwiftCut Precision",
    "SolarBlade 4000",
    "MegaSaw Turbo",
    "GreenCut HarmonyPro",
    "PrecisionBlade X4",
    "EcoSaw Pro",
    "TitanBlade Max-3",
    "SwiftSaw Precision",
    "MegaCut TurboMax",
]

circular_saw_manufacturers = [
    "QuantumTech Industries",
    "EnviroTech Saws",
    "TitanCraft Engineering",
    "QuantumTech Industries",
    "EnviroTech Saws",
    "TitanCraft Engineering",
    "EnviroTech Saws",
    "QuantumTech Industries",
    "EnviroTech Saws",
    "TitanCraft Engineering",
    "QuantumTech Industries",
    "TitanCraft Engineering",
]

circular_saw_descriptions = [
    "The CircuMax Pro-3000 is a high-performance circular saw designed for woodworking enthusiasts and professionals. With its powerful motor and precision blade, this circular saw delivers accurate and efficient cuts. The CircuMax Pro-3000 is a top choice for those seeking reliability and versatility in their cutting projects.",
    "The EcoBlade Elite is an environmentally conscious circular saw from EnviroTech Saws. Powered by a rechargeable eco-battery, this saw combines cutting-edge technology with sustainability. Ideal for various materials, the EcoBlade Elite is perfect for users who prioritize both performance and eco-friendly practices in their projects.",
    "The TitanSaw Master-2 is an upgraded version of TitanCraft Engineering's renowned circular saw. With enhanced cutting speed and precision, this saw is a reliable companion for professionals tackling demanding projects. The TitanSaw Master-2 excels in providing accurate and efficient results, making it a go-to choice for woodworking experts.",
    "The SwiftCut Precision is a compact and agile circular saw designed for quick and precise cuts. With its swift cutting mechanism and ergonomic design, this saw is perfect for users who need a versatile tool for on-the-go projects. DIYers and hobbyists appreciate the SwiftCut Precision for its portability and accuracy.",
    "The SolarBlade 4000 is a state-of-the-art solar-powered circular saw that combines efficiency with environmental sustainability. Perfect for light to medium-duty tasks, this saw's innovative energy source provides users with a reliable and eco-friendly option for their cutting needs.",
    "The MegaSaw Turbo is a powerhouse in the world of circular saws, brought to you by TitanCraft Engineering. With its high-speed turbocharged cutting system and heavy-duty construction, this saw tackles the toughest materials with ease. The MegaSaw Turbo is the ultimate choice for professionals seeking maximum performance and durability in their cutting tools.",
    "The GreenCut HarmonyPro is a revolutionary circular saw that sets new standards in sustainability and performance. Powered by a combination of solar energy and recycled materials, this environmentally conscious saw is ideal for users who prioritize green technology without compromising on cutting precision. The GreenCut HarmonyPro is the perfect blend of eco-friendliness and top-notch cutting capabilities.",
    "The PrecisionBlade X4 is a high-precision circular saw designed for fine woodworking and crafting. With advanced laser-guided technology and customizable cutting patterns, this saw provides unmatched accuracy and versatility. DIY enthusiasts and artists appreciate the PrecisionBlade X4 for its ability to create intricate designs with ease.",
    "The EcoSaw Pro is an environmentally friendly circular saw from EnviroTech Saws. Powered by a rechargeable eco-battery, this saw combines efficiency with a commitment to sustainability. Perfect for various materials, the EcoSaw Pro is a go-to choice for users who value both performance and eco-consciousness in their projects.",
    "The TitanBlade Max-3 is a rugged and versatile circular saw built for heavy-duty tasks. With its high cutting speed and durable construction, this powerhouse excels in cutting through various materials. The TitanBlade Max-3 is a reliable choice for professionals requiring strength and precision in their cutting endeavors.",
    "The SwiftSaw Precision is a compact and lightweight circular saw designed for fine detailing and intricate work. Its precise control and minimal vibration ensure a steady hand for delicate tasks. DIY hobbyists and artisans appreciate the SwiftSaw Precision for its ease of maneuverability and exceptional accuracy.",
    "The MegaCut TurboMax is a high-performance circular saw engineered for speed and power. With its turbocharged cutting mechanism and advanced cooling system, this saw excels in quick and efficient cutting tasks. The MegaCut TurboMax is the go-to choice for professionals who demand rapid results without compromising on durability.",
]

submodels = []

def manufacturer_to_submodel(name):
    manufacturer_name = aas_types.Property(id_short="Manufacturer Name", value_type=aas_types.DataTypeDefXSD.STRING, value=name)
    submodel = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Manufacturer",
        description=[aas_types.LangStringTextType("en", "Manufacturer of the asset")],
        submodel_elements=[
            manufacturer_name
        ]
    )
    submodels.append(submodel)
    return aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, submodel.id)])

def generate_energy_consumption():
    voltage_requirement = aas_types.Property(id_short="Required Voltage in volts", value_type=aas_types.DataTypeDefXSD.INT, value=str(random.randint(1, 10)))
    current_requirement = aas_types.Property(id_short="Required Current in amperes", value_type=aas_types.DataTypeDefXSD.INT, value=str(random.randint(1, 10)))
    submodel = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Energy Consumption",
        description=[aas_types.LangStringTextType("en", "How much electricity the asset consumes in operation.")],
        submodel_elements=[
            voltage_requirement,
            current_requirement
        ]
    )
    submodels.append(submodel)

    return aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, submodel.id)])

for i, drill_name in enumerate(drill_names):
    aas_info = aas_types.AssetInformation(asset_kind=aas_types.AssetKind.TYPE)

    hole_size = aas_types.Property(id_short="Hole Diameter in millimeters", value_type=aas_types.DataTypeDefXSD.DOUBLE, value=str(random.randint(1, 100) / 10))
    hole_depth = aas_types.Property(id_short="Hole Depth in millimeters", value_type=aas_types.DataTypeDefXSD.DOUBLE, value=str(random.randrange(1, 1000) / 10))
    drilling = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Drilling",
        description=[aas_types.LangStringTextType("en", "Hole drilling capability of the asset")],
        submodel_elements=[
            hole_size,
            hole_depth
        ]
    )
    
    submodels.append(drilling)

    ref = aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, drilling.id)])
    aas = aas_types.AssetAdministrationShell(id=generate_random_string(), asset_information=aas_info, description=[aas_types.LangStringTextType("en", drill_descriptions[i])], id_short=drill_name,
                                            submodels=[ref, manufacturer_to_submodel(drill_manufacturers[i]), generate_energy_consumption()])
    aass.append(aas)

for i, circle_cutter in enumerate(circle_cutter_names):
    aas_info = aas_types.AssetInformation(asset_kind=aas_types.AssetKind.TYPE)

    hole_size = aas_types.Property(id_short="Hole Diameter in centimeters", value_type=aas_types.DataTypeDefXSD.DOUBLE, value=str(random.randint(1, 100) / 10))
    hole_depth = aas_types.Property(id_short="Hole Depth in centimeters", value_type=aas_types.DataTypeDefXSD.DOUBLE, value=str(random.randrange(1, 1000) / 10))
    circle_cutting = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Circle Cutting",
        description=[aas_types.LangStringTextType("en", "Circular hole cutting capability of the asset")],
        submodel_elements=[
            hole_size,
            hole_depth
        ]
    )

    submodels.append(circle_cutting)
    
    ref = aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, circle_cutting.id)])
    aas = aas_types.AssetAdministrationShell(id=generate_random_string(), asset_information=aas_info, description=[aas_types.LangStringTextType("en", circle_cutter_descriptions[i])], id_short=circle_cutter,
                                            submodels=[ref, manufacturer_to_submodel(circle_cutter_manufacturers[i]), generate_energy_consumption()])
    aass.append(aas)

for i, circular_saw in enumerate(circular_saw_names):
    aas_info = aas_types.AssetInformation(asset_kind=aas_types.AssetKind.TYPE)

    depth = aas_types.Property(id_short="Circular saw cutting depth in millimeters", value_type=aas_types.DataTypeDefXSD.DOUBLE, value=str(random.randrange(1, 1000) / 10))
    sawing = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Sawing",
        description=[aas_types.LangStringTextType("en", "Sawing capability of the asset")],
        submodel_elements=[
            depth
        ]
    )

    submodels.append(sawing)

    ref = aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, sawing.id)])
    aas = aas_types.AssetAdministrationShell(id=generate_random_string(), asset_information=aas_info, description=[aas_types.LangStringTextType("en", circular_saw_descriptions[i])], id_short=circular_saw,
                                            submodels=[ref, manufacturer_to_submodel(circular_saw_manufacturers[i]), generate_energy_consumption()])
    aass.append(aas)

for i in range(1000):
    aas_info = aas_types.AssetInformation(asset_kind=aas_types.AssetKind.INSTANCE)

    is_available = aas_types.Property(id_short="Asset is available for use", value_type=aas_types.DataTypeDefXSD.BOOLEAN, value=str(random.choice([True, False])))
    availability = aas_types.Submodel(
        id=generate_random_string(),
        id_short="Availability",
        description=[aas_types.LangStringTextType("en", "Whether the asset is available for use")],
        submodel_elements=[
            is_available
        ],
    )
    submodels.append(availability)
    ref = aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.SUBMODEL, availability.id)])
    aas = aas_types.AssetAdministrationShell(id=generate_random_string(), asset_information=aas_info, description=[aas_types.LangStringTextType("en", "A specific machine")], id_short="Machine #" + str(i),
                                            submodels=[ref], derived_from=aas_types.Reference(type = aas_types.ReferenceTypes.MODEL_REFERENCE, keys = [aas_types.Key(aas_types.KeyTypes.GLOBAL_REFERENCE, random.choice(aass[:26]).id)]))
    aass.append(aas)
# aas_types.AssetAdministrationShell(id=generate_random_string(), asset_information=aas_info, description=[aas_types.LangStringTextType("en", "bla")]
    

environment = aas_types.Environment(asset_administration_shells=aass, submodels=submodels)
print(json.dumps(aas_jsonization.to_jsonable(environment), indent=2))
with open("example.json", 'w') as json_file:
    json.dump(aas_jsonization.to_jsonable(environment), json_file, indent=2)
# Out:
# {
#   "assetAdministrationShells": [
#     {
#       "idShort": "QuantumPro X1",
#       "description": [
#         {
#           "language": "en",
#           "text": "The QuantumPro X1 is a precision drilling marvel designed for woodworking enthusiasts. With its advanced gyroscopic stabilization technology and variable speed control, this driller ensures unparalleled accuracy and ease of use. Its sleek design and ergonomic grip make it a favorite among DIYers and professionals alike."
#         }
#       ],
#       "id": "Cv09FgoBJL",
#       "assetInformation": {
#         "assetKind": "Type"
#       },
#       "submodels": [
#         {
#           "type": "ModelReference",
#           "keys": [
#             {
#               "type": "Submodel",
#               "value": "b8oCzMq3cF"
#             }
#           ]
#         },
#         {
#           "type": "ModelReference",
#           "keys": [
#             {
#               "type": "Submodel",
# ...

# %%
print(submodels)
# Out:
# [<aas_core3.types.Submodel object at 0x77e4fafd6a10>, <aas_core3.types.Submodel object at 0x77e4fafd64a0>, <aas_core3.types.Submodel object at 0x77e4fafd6710>, <aas_core3.types.Submodel object at 0x77e4fad30250>, <aas_core3.types.Submodel object at 0x77e4fad30880>, <aas_core3.types.Submodel object at 0x77e4fad30c40>, <aas_core3.types.Submodel object at 0x77e4fad31180>, <aas_core3.types.Submodel object at 0x77e4fad31570>, <aas_core3.types.Submodel object at 0x77e4fad31ae0>, <aas_core3.types.Submodel object at 0x77e4fad31f00>, <aas_core3.types.Submodel object at 0x77e4fad32470>, <aas_core3.types.Submodel object at 0x77e4fad32830>, <aas_core3.types.Submodel object at 0x77e4fad32bf0>, <aas_core3.types.Submodel object at 0x77e4fad330d0>, <aas_core3.types.Submodel object at 0x77e4fad334c0>, <aas_core3.types.Submodel object at 0x77e4fad33af0>, <aas_core3.types.Submodel object at 0x77e4fad33e50>, <aas_core3.types.Submodel object at 0x77e4fad30370>, <aas_core3.types.Submodel object at 0x77e4f
# ...

# %%
with open('example.json', 'r') as json_file:
    data = json.load(json_file)

environment = aas_jsonization.environment_from_jsonable(
            aas_jsonization.to_jsonable(environment)
        )

# %%
from rdflib import Graph, URIRef, Literal, ConjunctiveGraph
from urllib.parse import quote_plus, unquote_plus
graph = Graph()
# for triple in triples:
#         print(triple)
#         for key in triple['readable']:
#             print(key)
#             self.add_auxilary_triples(triple['readable'][key], triple['processed'][key], graph)
#         proc_triple = triple['processed']
#         print(proc_triple)
#         graph.add((URIRef(proc_triple['subject']), URIRef(proc_triple['predicate']), URIRef(proc_triple['object'])))
#     self.graph_write += graph

uri = "http://example.com/"
literal_uri = "http://example.com/literal/"
def get_uri(text, is_literal=False):
     if is_literal:
         return URIRef(literal_uri + text)
     return URIRef(uri + text)

def add_triple(a, b, c, last_is_literal=False):
    # print(a, b, c)
    graph.add(map(lambda e : get_uri(quote_plus(str(e)), True if last_is_literal and e == c else False), (a, b, c)))
for e in environment.descend():
    # print(type(something) == aas_types.AssetAdministrationShell, dir(something))
    if (type(e) == aas_types.AssetAdministrationShell):
        if e.asset_information.asset_kind == aas_types.AssetKind.INSTANCE:
            add_triple(e.id, "is instance of", e.derived_from.keys[0].value)
        for submodel in e.submodels:
            add_triple(submodel.keys[0].value, f'is part of / describes', e.id)
        add_triple(e.id, "has description", e.description[0].text, True)
        add_triple(e.id, "has name", e.id_short, True)
    elif (type(e) == aas_types.Submodel):
        add_triple(e.id, "has name", e.id_short, True)
        add_triple(e.id, "has description", e.description[0].text, True)
        for submodel_element in e.submodel_elements:
            add_triple(e.id, f'has "{submodel_element.id_short}" value', submodel_element.value, True)

# %%
print(aass[:26])
print(aass[25].id_short)
# Out:
# [<aas_core3.types.AssetAdministrationShell object at 0x77e4fad300a0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad30f10>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad31c90>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad329e0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad336d0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad304c0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad31000>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad317e0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad32350>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad32950>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad33790>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad710c0>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad70c70>, <aas_core3.types.AssetAdministrationShell object at 0x77e4fad70700>, <aas_core3.types.AssetAdministr
# ...
