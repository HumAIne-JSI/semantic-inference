# %%
addr = "http://127.0.0.1:5000"
payload = {
    "breadth": 1000,
    "scope": 100,
    "score_weight": 100,
    "llmModel": "gpt-4-1106-preview",
    "useQueryGeneration": True,
}
def set_payload(**to_set):
    for key, value in to_set.items():
        payload[key] = value

# %%
import requests

def run_query(
    query_input
) -> str:
    # Define the payload for the POST request
    set_payload(query=query_input)

    try:
        # Send the POST request
        response = requests.post(f"{addr}/query", json=payload)
        response.raise_for_status()  # Raise an exception for HTTP errors
        query_output = response.json().get("answer")
        return query_output
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
while True:
    print(run_query("Get number of available EcoRound Precision machine instances. Specify the number for each machine type separately."))
# Out:
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the information provided, there are 23 available instances of the EcoRound Precision machine. This number represents the total count of individual machines of the EcoRound Precision model that are currently available for use.
# Based on the provided information, the EcoRound Precision machine has one instance named "Machine #620" that is available for use. The availability is indicated by the "Availability" property with a value of 'True'. Therefore, the number of available EcoRound Precision machine instances is 1.
# Based on the provided information, the EcoRound Precision does not have any directly associated machine instances listed under its name or description. Therefore, it is not possible to specify the number of available EcoRound Precision machine instances as no specific machines are described as part of or instances of the EcoRound Precision asset.
# Based on the provided information, the EcoRound Precision machine instances that are available are as follows:
#
# - Machine #620 is available.
#
# There is only one instance of the EcoRound Precision machine mentioned as being available, which is Machine #620.
# The number of available EcoRound Precision machine instances is 23.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine. This number represents the total count of machines under the EcoRound Precision model that are currently available for use.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# There are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, the EcoRound Precision machine instances and their availability status are as follows:
#
# - Machine #620 is available for use.
#
# This indicates that there is 1 available EcoRound Precision machine instance.
# There are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there is only one instance of the EcoRound Precision machine mentioned. The details provided describe various aspects of the EcoRound Precision, such as its sustainability features, energy consumption, and circle cutting capabilities, but they all refer back to the single instance of the EcoRound Precision machine. There are no separate machine types or additional instances indicated in the information given.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine. This number represents the total count of machines under the EcoRound Precision model that are currently available for use.
# Based on the information provided, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the information provided, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, the EcoRound Precision machine has one specific instance named "Machine #620" that is mentioned as being available for use. There are no other instances of the EcoRound Precision machine explicitly mentioned as being available or not available. Therefore, for the EcoRound Precision machine:
#
# - Machine #620: Available
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, the EcoRound Precision machine has one instance named "Machine #620" that is available for use. This is determined from the information that "Machine #620" is an instance of "EcoRound Precision" and it has an "Availability" property with a value of 'True'.
#
# Therefore, the number of available EcoRound Precision machine instances is:
# - Machine #620: 1 available
# Based on the information provided, there are 23 available instances of the EcoRound Precision machine.
# Based on the provided information, the EcoRound Precision machine has one instance named "Machine #620" that is available for use. There are no other specific machine instances mentioned under the EcoRound Precision asset, so the number of available machines for the EcoRound Precision type is:
#
# - Machine #620: 1 available
# Based on the provided information, the EcoRound Precision machine has one specific instance named "Machine #620" that is available for use. There are no other instances of the EcoRound Precision machine mentioned in the context, so the number of available EcoRound Precision machines is:
#
# - Machine #620: 1 available
# Based on the provided information, there is only one instance of the EcoRound Precision machine mentioned. The details provided describe various aspects of this single instance, including its manufacturer, energy consumption, and circle cutting capabilities. However, there is no direct information on the number of available instances beyond the single instance described. Therefore, the number of available EcoRound Precision machine instances is one.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[197], line 2
#       1 while True:
# ----> 2     print(run_query("Get number of available EcoRound Precision machine instances. Specify the number for each machine type separately."))
#
# Cell In[183], line 11, in run_query(query_input)
#       7 set_payload(query=query_input)
#       9 try:
#      10     # Send the POST request
# ---> 11     response = requests.post(f"{addr}/query", json=payload)
#      12     response.raise_for_status()  # Raise an exception for HTTP errors
#      13     query_output = response.json().get("answer")
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(run_query("Get number of available SwiftSaw Precision, MegaCut TurboMax, EcoSaw Pro, SolarSphere 3000, SolarBlade 4000, SwiftDrill Precision, TitanBlade Max-3, MegaRound Turbo, CirclerPro X2 machine instances. Specify the number for each machine type separately."))
# Out:
# Based on the information provided, here are the available instances for each specified machine type:
#
# - SwiftSaw Precision: 16 available instances
# - MegaCut TurboMax: 23 available instances
# - EcoSaw Pro: 19 available instances
# - SolarSphere 3000: 13 available instances
# - SolarBlade 4000: 20 available instances
# - SwiftDrill Precision: 23 available instances
# - TitanBlade Max-3: 19 available instances
# - MegaRound Turbo: 12 available instances
# - CirclerPro X2: 28 available instances
#
# These numbers represent the count of available instances for each machine type as per the latest query response.

# %%
to_fix = """SELECT ?machine_model_name (COUNT(?machine_instance_id) AS ?available_instances)
WHERE {
  # ?machine_instance_id <http://www.frequent-predicate/is+instance+of> ?machine_model_id .
  # ?machine_model_id <http://www.entity-with-random-id/has+name> ?machine_model_name .
  # ?availability_submodel_id <http://www.entity-with-random-id/is+part+of+%2F+describes> ?machine_instance_id .
  # ?availability_submodel_id <http://www.entity-with-random-id/has+%22Asset+is+available+for+use%22+value> <http://www.value/True> .
  FILTER(?machine_model_name IN (<http://www.value/SwiftSaw Precision>, <http://www.value/MegaCut TurboMax>, <http://www.value/EcoSaw Pro>, <http://www.value/SolarSphere 3000>, <http://www.value/SolarBlade 4000>, <http://www.value/SwiftDrill Precision>, <http://www.value/TitanBlade Max-3>, <http://www.value/MegaRound Turbo>, <http://www.value/CirclerPro X2>))
}
GROUP BY ?machine_model_name"""
print(re.sub(r'<([^<>]*)>', lambda match: '<' + match.group(1).replace(' ', '+') + '>', to_fix))
# Out:
# SELECT ?machine_model_name (COUNT(?machine_instance_id) AS ?available_instances)
# WHERE {
#   ?machine_instance_id <http://www.frequent-predicate/is+instance+of> ?machine_model_id .
#   ?machine_model_id <http://www.entity-with-random-id/has+name> ?machine_model_name .
#   ?availability_submodel_id <http://www.entity-with-random-id/is+part+of+%2F+describes> ?machine_instance_id .
#   ?availability_submodel_id <http://www.entity-with-random-id/has+%22Asset+is+available+for+use%22+value> <http://www.value/True> .
#   FILTER(?machine_model_name IN (<http://www.value/SwiftSaw+Precision>, <http://www.value/MegaCut+TurboMax>, <http://www.value/EcoSaw+Pro>, <http://www.value/SolarSphere+3000>, <http://www.value/SolarBlade+4000>, <http://www.value/SwiftDrill+Precision>, <http://www.value/TitanBlade+Max-3>, <http://www.value/MegaRound+Turbo>, <http://www.value/CirclerPro+X2>))
# }
# GROUP BY ?machine_model_name

# %%
import json
names = ["drilling machines", "circle cutters", "circular saws"]
data = []
for name in names:
    for i in range(11):
        query = f"Return all {name} that consume at most {i} volts and specify their consumption."
        # print(query)
        data.append({'type': name, 'query': run_query(query), 'voltage': i, 'question': query})
# Out:
# Return all drilling machines that consume at most 0 volts and specify their consumption.
# Return all drilling machines that consume at most 1 volts and specify their consumption.
# Return all drilling machines that consume at most 2 volts and specify their consumption.
# Return all drilling machines that consume at most 3 volts and specify their consumption.
# Return all drilling machines that consume at most 4 volts and specify their consumption.
# Return all drilling machines that consume at most 5 volts and specify their consumption.
# Return all drilling machines that consume at most 6 volts and specify their consumption.
# Return all drilling machines that consume at most 7 volts and specify their consumption.
# Return all drilling machines that consume at most 8 volts and specify their consumption.
# Return all drilling machines that consume at most 9 volts and specify their consumption.
# Return all drilling machines that consume at most 10 volts and specify their consumption.
# Return all circle cutters that consume at most 0 volts and specify their consumption.
# Return all circle cutters that consume at most 1 volts and specify their consumption.
# Return all circle cutters that consume at most 2 volts and specify their consumption.
# Return all circle cutters that consume at most 3 volts and specify their consumption.
# Return all circle cutters that consume at most 4 volts and specify their consumption.
# Return all circle cutters that consume at most 5 volts and specify their consumption.
# Return all circle cutters that consume at most 6 volts and specify their consumption.
# Return all circle cutters that consume at most 7 volts and specify their consumption.
# Return all circle cutters that consume at most 8 volts and specify their consumption.
# Return all circle cutters that consume at most 9 volts and specify their consumption.
# Return all circle cutters that consume at most 10 volts and specify their consumption.
# Return all circular saws that consume at most 0 volts and specify their consumption.
# Return all circular saws that consume at most 1 volts and specify their consumption.
# Return all circular saws that consume at most 2 volts and specify their consumption.
# Return all circular saws that consume at most 3 volts and specify their consumption.
# Return all circular saws that consume at most 4 volts and specify their consumption.
# Return all circular saws that consume at most 5 volts and specify their consumption.
# Return all circular saws that consume at most 6 volts and specify their consumption.
# Return all circular saws that consume at most 7 volts and specify their consumption.
# Return all circular saws that consume at most 8 volts and specify their consumption.
# Return all circular saws that consume at most 9 volts and specify their consumption.
# Return all circular saws that consume at most 10 volts and specify their consumption.

# %%
print(data[12])
# Out:
# {'type': 'circle cutters', 'query': 'The circle cutters that consume at most 1 volt and their consumption details are:\n\n1. **SwiftCircle Elite** - Energy Consumption: 1 volt and 1 ampere.\n2. **MegaRound Turbo** - Energy Consumption: 1 volt and 7 amperes.', 'voltage': 1, 'question': 'Return all circle cutters that consume at most 1 volts and specify their consumption.'}

# %%
with open('res.json', 'w') as file:
    json.dump(data, file, indent=4)  # indent=4 for pretty-printing

# %%
import json

import aas_core3.jsonization as aas_jsonization

with open('./../generation/example.json', 'r') as file:
    jsonable = json.load(file)

environment = aas_jsonization.environment_from_jsonable(
    jsonable
)

# %%
import aas_core3.types as aas_types

key_to_submodel = {}
name_to_aas={}
key_to_name = {}
for submodel in environment.descend():
    if isinstance(submodel, aas_types.Submodel):
        key_to_submodel[submodel.id] = submodel
        # for submodel in aas.submodels:
        #     print(submodel.keys[0].value)
for aas in environment.descend():
    if isinstance(aas, aas_types.AssetAdministrationShell) and aas.asset_information.asset_kind != aas_types.AssetKind.INSTANCE:
        print(aas.id_short)
        res = {'name': aas.id_short}
        for submodel_key in aas.submodels:
            submodel = key_to_submodel[submodel_key.keys[0].value]
            if submodel.id_short == 'Energy Consumption':
                res['voltage'] = int(submodel.submodel_elements[0].value)
            elif submodel.id_short != 'Manufacturer':
                res['type'] = submodel.id_short
            submodel.id_short
        name_to_aas[aas.id_short]=res
        key_to_name[aas.id] = aas.id_short
        print(res)
        print()

name_to_num_of_instances = {}
for name in name_to_aas.keys():
    name_to_num_of_instances[name] = 0
for aas in environment.descend():
    if isinstance(aas, aas_types.AssetAdministrationShell) and aas.asset_information.asset_kind == aas_types.AssetKind.INSTANCE:
        if key_to_submodel[aas.submodels[0].keys[0].value].submodel_elements[0].value == 'True':
            name_to_num_of_instances[key_to_name[aas.derived_from.keys[0].value]] += 1
        # if aas.
print(name_to_num_of_instances)
# Out:
# QuantumPro X1
# {'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}
#
# EcoDrive Elite
# {'name': 'EcoDrive Elite', 'type': 'Drilling', 'voltage': 10}
#
# TitanCraft Pro-1
# {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}
#
# SwiftDrill Precision
# {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}
#
# SolarSprint 2000
# {'name': 'SolarSprint 2000', 'type': 'Drilling', 'voltage': 7}
#
# MegaForce Turbo
# {'name': 'MegaForce Turbo', 'type': 'Drilling', 'voltage': 9}
#
# GreenHarmony EcoPro
# {'name': 'GreenHarmony EcoPro', 'type': 'Drilling', 'voltage': 9}
#
# CirclerPro X2
# {'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}
#
# EcoRound Precision
# {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}
#
# TitanCut CircleMaster
# {'name': 'TitanCut CircleMaster', 'type': 'Circle Cutting', 'voltage': 8}
#
# SwiftCircle Elite
# {'name': 'SwiftCircle Elite', 'type': 'Circle Cutting', 'voltage': 10}
#
# SolarSphere 3000
# {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}
#
# MegaRound Turbo
# {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}
#
# GreenCirc HarmonyPro
# {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}
#
# CircuMax Pro-3000
# {'name': 'CircuMax Pro-3000', 'type': 'Sawing', 'voltage': 7}
#
# EcoBlade Elite
# {'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}
#
# TitanSaw Master-2
# {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}
#
# SwiftCut Precision
# {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}
#
# SolarBlade 4000
# {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}
#
# MegaSaw Turbo
# {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}
#
# GreenCut HarmonyPro
# {'name': 'GreenCut HarmonyPro', 'type': 'Sawing', 'voltage': 10}
#
# PrecisionBlade X4
# {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}
#
# EcoSaw Pro
# {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}
#
# TitanBlade Max-3
# {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}
#
# SwiftSaw Precision
# {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}
#
# MegaCut TurboMax
# {'name': 'MegaCut TurboMax', 'type': 'Sawing', 'voltage': 10}
#
# {'QuantumPro X1': 30, 'EcoDrive Elite': 22, 'TitanCraft Pro-1': 17, 'SwiftDrill Precision': 23, 'SolarSprint 2000': 25, 'MegaForce Turbo': 17, 'GreenHarmony EcoPro': 21, 'CirclerPro X2': 28, 'EcoRound Precision': 23, 'TitanCut CircleMaster': 22, 'SwiftCircle Elite': 19, 'SolarSphere 3000': 13, 'MegaRound Turbo': 12, 'GreenCirc HarmonyPro': 22, 'CircuMax Pro-3000': 15, 'EcoBlade Elite': 14, 'TitanSaw Master-2': 24, 'SwiftCut Precision': 21, 'SolarBlade 4000': 20, 'MegaSaw Turbo': 14, 'GreenCut HarmonyPro': 17, 'PrecisionBlade X4': 22, 'EcoSaw Pro': 19, 'TitanBlade Max-3': 19, 'SwiftSaw Precision': 16, 'MegaCut TurboMax': 23}

# %%
import re
with open('./res.json', 'r') as file:
    query_answers = json.load(file)

to_actual={'drilling machines':"Drilling", 'circular saws': 'Sawing', 'circle cutters': 'Circle Cutting'}

# Find all voltage values
# voltage_values = re.findall(voltage_pattern, text)
def find_actual(typ, upper_bound_voltage):
    res = []
    for name, aas in name_to_aas.items():
        if (aas['type']==typ and aas['voltage']<=upper_bound_voltage):
            res.append(aas)
    return res

for query in query_answers:
    actual_type = to_actual[query['type']]
    name_pattern = r'\*\*(.*?)\*\*'

    # Regular expression to find the voltage value that comes after the name
    voltage_pattern = r'(\d+) volts'

    # Find all machine names
    machine_names = re.findall(name_pattern, query['query'])

    # Find all voltage values
    voltage_values = []
    if ('\n' in query['query']):
        # print('here')
        # print(query['query'].split('\n', 2))
        voltage_values = re.findall(voltage_pattern, query['query'].split('\n', 1)[1])

    # Combine names and their corresponding voltages
    machines_with_voltage = list(zip(machine_names, voltage_values))
    # print(actual_type)
    # print(machine_names)
    # print(voltage_values)
    print(query['query'])
    # if len(machines_with_voltage) > 0:
    #     print(type(machines_with_voltage[0][0]))
    additional = 0
    hit = 0
    wrong_voltage = 0
    actual = find_actual(actual_type, query['voltage'])
    for actual_aas in actual:
        for val in machines_with_voltage:
            machine, voltage = val
            if (actual_aas['name'] == machine):
                hit += 1
                if actual_aas['voltage'] != int(voltage):
                    wrong_voltage += 1
                machines_with_voltage.remove(val)
                break
    additional = len(machines_with_voltage)
    print('cur: ' + str(query['voltage']))
    print(f"{hit} of {len(actual)} {actual}")
    print(f"wrong voltage: {wrong_voltage}")
    print(f"additional: {additional}")
    # print(machines_with_voltage)
    print(machine_names)
    print(voltage_values)

    print()
# Out:
# Based on the provided information, there are no drilling machines listed that consume at most 0 volts. All the drilling machines mentioned have a specified electrical consumption that requires more than 0 volts to operate.
# cur: 0
# 0 of 0 []
# wrong voltage: 0
# additional: 0
# []
# []
#
# Based on the provided information, there are no drilling machines listed that consume at most 1 volt. All the drilling machines mentioned have a higher voltage consumption as part of their energy consumption characteristics.
# cur: 1
# 0 of 0 []
# wrong voltage: 0
# additional: 0
# []
# []
#
# The drilling machines that consume at most 2 volts and their consumption are:
#
# 1. **SwiftDrill Precision** - It consumes 2 volts and 2 amperes of electricity. This compact and lightweight driller is designed for fine detailing and intricate work, appreciated by DIY hobbyists and artisans for its precise control and minimal vibration.
#
# 2. **MegaForce Turbo** - It consumes 2 volts and 2 amperes of electricity. This high-performance driller is engineered for speed and power, featuring a turbocharged motor and advanced cooling system, making it the go-to choice for professionals seeking rapid results without compromising durability.
# cur: 2
# 1 of 1 [{'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}]
# wrong voltage: 0
# additional: 1
# ['SwiftDrill Precision', 'MegaForce Turbo']
# ['2', '2']
#
# The drilling machines that consume at most 3 volts and their respective consumption are:
#
# 1. **EcoDrive Elite** - It consumes 3 volts and 3 amperes.
# 2. **SwiftDrill Precision** - It consumes 2 volts and 2 amperes.
# 3. **MegaForce Turbo** - It consumes 9 volts and 2 amperes. (Note: This exceeds the voltage criteria but is included for completeness based on the available data structure. For strict adherence to the question, this entry should be disregarded.)
# 4. **QuantumPro X1** - It consumes 3 volts and 3 amperes.
# 5. **SolarSprint 2000** - It consumes 7 volts and 10 amperes. (Note: This exceeds the voltage criteria and should be disregarded based on the question's criteria.)
#
# From the list, only **EcoDrive Elite**, **SwiftDrill Precision**, and **QuantumPro X1** strictly meet the criteria of consuming at most 3 volts.
# cur: 3
# 2 of 2 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}]
# wrong voltage: 0
# additional: 4
# ['EcoDrive Elite', 'SwiftDrill Precision', 'MegaForce Turbo', 'QuantumPro X1', 'SolarSprint 2000', 'EcoDrive Elite', 'SwiftDrill Precision', 'QuantumPro X1']
# ['3', '2', '9', '3', '7', '3']
#
# The drilling machines that consume at most 4 volts and their respective consumption are:
#
# 1. **EcoDrive Elite** - It requires 3 volts and 3 amperes for its operation, as indicated by its energy consumption details.
# 2. **SwiftDrill Precision** - This machine operates on 2 volts and 2 amperes, showcasing its efficient energy consumption.
# 3. **QuantumPro X1** - It consumes electricity at 3 volts and 3 amperes, aligning with its energy usage specifications.
#
# These drilling machines are designed with energy efficiency in mind, catering to users who prioritize both performance and sustainability.
# cur: 4
# 2 of 2 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}]
# wrong voltage: 0
# additional: 1
# ['EcoDrive Elite', 'SwiftDrill Precision', 'QuantumPro X1']
# ['3', '2', '3']
#
# Based on the provided information, the drilling machines that consume at most 5 volts and their consumption details are:
#
# 1. **SwiftDrill Precision** consumes 2 volts and 2 amperes.
# 2. **MegaForce Turbo** consumes 9 volts and 2 amperes. (Note: This entry does not meet the criteria of consuming at most 5 volts but is included for completeness based on the provided data structure. Please disregard based on the specified criteria.)
# 3. **QuantumPro X1** consumes 3 volts and 3 amperes.
# cur: 5
# 2 of 2 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}]
# wrong voltage: 1
# additional: 1
# ['SwiftDrill Precision', 'MegaForce Turbo', 'QuantumPro X1']
# ['2', '9', '5', '3']
#
# The drilling machines that consume at most 6 volts and their consumption details are:
#
# 1. **SwiftDrill Precision** consumes 2 volts and 2 amperes.
# 2. **MegaForce Turbo** consumes 9 volts and 2 amperes. (Although it consumes 2 amperes, it exceeds the voltage requirement, so it should not be listed according to the specified criteria of at most 6 volts. This is corrected for accuracy.)
# 3. **SolarSprint 2000** consumes 7 volts and 10 amperes. (This also exceeds the voltage requirement and is incorrectly listed, correcting for accuracy.)
#
# Correcting the oversight, the only drilling machine that fits the criteria of consuming at most 6 volts is:
#
# - **SwiftDrill Precision**, which consumes 2 volts and 2 amperes.
# cur: 6
# 1 of 3 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}]
# wrong voltage: 0
# additional: 3
# ['SwiftDrill Precision', 'MegaForce Turbo', 'SolarSprint 2000', 'SwiftDrill Precision']
# ['2', '9', '6', '7', '6', '2']
#
# The drilling machines that consume at most 7 volts and their respective consumption details are:
#
# 1. **EcoDrive Elite** consumes 10 volts and 3 amperes.
# 2. **SwiftDrill Precision** consumes 2 volts and 2 amperes.
# 3. **MegaForce Turbo** consumes 9 volts and 2 amperes.
# 4. **QuantumPro X1** consumes 3 volts and 3 amperes.
# 5. **SolarSprint 2000** consumes 7 volts and 10 amperes.
#
# Among these, the **SwiftDrill Precision** and **QuantumPro X1** are the ones that meet the criteria of consuming at most 7 volts. Specifically:
# - **SwiftDrill Precision** has an energy consumption of 2 volts and 2 amperes.
# - **QuantumPro X1** has an energy consumption of 3 volts and 3 amperes.
# cur: 7
# 3 of 4 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}, {'name': 'SolarSprint 2000', 'type': 'Drilling', 'voltage': 7}]
# wrong voltage: 0
# additional: 5
# ['EcoDrive Elite', 'SwiftDrill Precision', 'MegaForce Turbo', 'QuantumPro X1', 'SolarSprint 2000', 'SwiftDrill Precision', 'QuantumPro X1', 'SwiftDrill Precision', 'QuantumPro X1']
# ['10', '2', '9', '3', '7', '7', '2', '3']
#
# Based on the provided information, the drilling machines that consume at most 8 volts and their respective consumption details are:
#
# 1. **EcoDrive Elite** - This drilling solution is powered by a cutting-edge solar-charged battery, emphasizing efficiency and environmental responsibility. It has an energy consumption feature requiring 10 volts and 3 amperes, which exceeds the specified maximum of 8 volts.
#
# 2. **SwiftDrill Precision** - A compact and lightweight driller designed for fine detailing and intricate work, appreciated for its precise control and minimal vibration. It has an energy consumption feature requiring 2 volts and 2 amperes, fitting the criteria of consuming at most 8 volts.
#
# 3. **MegaForce Turbo** - Engineered for speed and power with a turbocharged motor and advanced cooling system, this high-performance driller is ideal for quick and efficient drilling tasks. It has an energy consumption feature requiring 9 volts and 2 amperes, which exceeds the specified maximum of 8 volts.
#
# 4. **QuantumPro X1** - A precision drilling marvel with advanced gyroscopic stabilization technology and variable speed control, designed for woodworking enthusiasts. It has an energy consumption feature requiring 3 volts and 3 amperes, fitting the criteria of consuming at most 8 volts.
#
# 5. **SolarSprint 2000** - A solar-powered driller combining efficiency with environmental sustainability, perfect for light to medium-duty tasks. It has an energy consumption feature requiring 7 volts and 10 amperes, fitting the criteria of consuming at most 8 volts.
#
# 6. **GreenHarmony EcoPro** - A revolutionary driller powered by solar energy and recycled materials, setting new standards in sustainability and performance. The specific voltage and amperage consumption for this model are not provided in the information, so it cannot be determined if it fits the criteria based on the available data.
#
# Among these, the **SwiftDrill Precision** and **QuantumPro X1** are the drilling machines that consume at most 8 volts, with their consumption being 2 volts and 2 amperes, and 3 volts and 3 amperes, respectively. The **SolarSprint 2000** also fits the criteria with a consumption of 7 volts and 10 amperes.
# cur: 8
# 3 of 4 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}, {'name': 'SolarSprint 2000', 'type': 'Drilling', 'voltage': 7}]
# wrong voltage: 3
# additional: 6
# ['EcoDrive Elite', 'SwiftDrill Precision', 'MegaForce Turbo', 'QuantumPro X1', 'SolarSprint 2000', 'GreenHarmony EcoPro', 'SwiftDrill Precision', 'QuantumPro X1', 'SolarSprint 2000']
# ['10', '8', '2', '8', '9', '8', '3', '8', '7', '8', '8', '2', '3', '7']
#
# Based on the provided information, the drilling machines that consume at most 9 volts and their respective consumption details are as follows:
#
# 1. **EcoDrive Elite** consumes 10 volts and 3 amperes. (Although it consumes 10 volts, which is slightly above the specified limit, it's included for completeness given the close threshold.)
#
# 2. **SwiftDrill Precision** consumes 2 volts and 2 amperes.
#
# 3. **MegaForce Turbo** consumes 9 volts and 2 amperes.
#
# 4. **QuantumPro X1** consumes 3 volts and 3 amperes.
#
# 5. **SolarSprint 2000** consumes 7 volts and 10 amperes.
#
# 6. **GreenHarmony EcoPro** does not have specific consumption values provided directly, but it is mentioned as being powered by solar energy and recycled materials, indicating a focus on sustainability and potentially low energy consumption. However, without explicit voltage and amperage values, it cannot be directly compared to the specified criteria.
# cur: 9
# 5 of 6 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}, {'name': 'SolarSprint 2000', 'type': 'Drilling', 'voltage': 7}, {'name': 'MegaForce Turbo', 'type': 'Drilling', 'voltage': 9}, {'name': 'GreenHarmony EcoPro', 'type': 'Drilling', 'voltage': 9}]
# wrong voltage: 5
# additional: 1
# ['EcoDrive Elite', 'SwiftDrill Precision', 'MegaForce Turbo', 'QuantumPro X1', 'SolarSprint 2000', 'GreenHarmony EcoPro']
# ['10', '10', '2', '9', '3', '7']
#
# Based on the provided information, the drilling machines that consume at most 10 volts and their respective consumption details are as follows:
#
# 1. **EcoDrive Elite**
#    - Required Voltage: 10 volts
#    - Required Current: 3 amperes
#    - Description: The EcoDrive Elite is a sustainable drilling solution for eco-conscious users, powered by a cutting-edge solar-charged battery. It combines efficiency with environmental responsibility and is ideal for various materials.
#
# 2. **SwiftDrill Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 2 amperes
#    - Description: The SwiftDrill Precision is a compact and lightweight driller designed for fine detailing and intricate work. It offers precise control and minimal vibration, making it appreciated by DIY hobbyists and artisans for its maneuverability and accuracy.
#
# 3. **MegaForce Turbo**
#    - Required Voltage: 9 volts
#    - Required Current: 2 amperes
#    - Description: The MegaForce Turbo is a high-performance driller engineered for speed and power, featuring a turbocharged motor and advanced cooling system. It is the go-to choice for professionals seeking rapid results without compromising durability.
#
# 4. **SolarSprint 2000**
#    - Required Voltage: 7 volts
#    - Required Current: 10 amperes
#    - Description: The SolarSprint 2000 is a state-of-the-art solar-powered driller that combines efficiency with environmental sustainability. It's perfect for light to medium-duty tasks, offering a reliable and eco-friendly option for drilling needs.
#
# These drilling machines are distinguished by their voltage consumption and are designed to cater to various user needs, from eco-conscious individuals to professionals requiring speed and power.
# cur: 10
# 4 of 7 [{'name': 'QuantumPro X1', 'type': 'Drilling', 'voltage': 3}, {'name': 'EcoDrive Elite', 'type': 'Drilling', 'voltage': 10}, {'name': 'TitanCraft Pro-1', 'type': 'Drilling', 'voltage': 6}, {'name': 'SwiftDrill Precision', 'type': 'Drilling', 'voltage': 2}, {'name': 'SolarSprint 2000', 'type': 'Drilling', 'voltage': 7}, {'name': 'MegaForce Turbo', 'type': 'Drilling', 'voltage': 9}, {'name': 'GreenHarmony EcoPro', 'type': 'Drilling', 'voltage': 9}]
# wrong voltage: 0
# additional: 0
# ['EcoDrive Elite', 'SwiftDrill Precision', 'MegaForce Turbo', 'SolarSprint 2000']
# ['10', '2', '9', '7']
#
# Based on the provided information, there are no circle cutters that consume at most 0 volts. All listed circle cutters have a specified electricity consumption that exceeds 0 volts.
# cur: 0
# 0 of 0 []
# wrong voltage: 0
# additional: 0
# []
# []
#
# The circle cutters that consume at most 1 volt and their consumption details are:
#
# 1. **SwiftCircle Elite** - Energy Consumption: 1 volt and 1 ampere.
# 2. **MegaRound Turbo** - Energy Consumption: 1 volt and 7 amperes.
# cur: 1
# 0 of 1 [{'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}]
# wrong voltage: 0
# additional: 0
# ['SwiftCircle Elite', 'MegaRound Turbo']
# []
#
# The circle cutters that consume at most 2 volts and their consumption details are:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
# cur: 2
# 2 of 3 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'EcoRound Precision']
# ['2', '2']
#
# The circle cutters that consume at most 3 volts and their respective consumption are:
#
# 1. **CirclerPro X2** - Consumes 2 volts and 6 amperes.
# 2. **EcoRound Precision** - Consumes 2 volts and 8 amperes.
# 3. **SolarSphere 3000** - Consumes 4 volts and 2 amperes. (Although this exceeds the 3 volts criteria, it was initially included due to an oversight. It should not be considered under the specified criteria of at most 3 volts consumption.)
# cur: 3
# 2 of 3 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}]
# wrong voltage: 0
# additional: 1
# ['CirclerPro X2', 'EcoRound Precision', 'SolarSphere 3000']
# ['2', '2', '4', '3', '3']
#
# The circle cutters that consume at most 4 volts and their consumption details are:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
# cur: 4
# 2 of 4 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'EcoRound Precision']
# ['2', '2']
#
# Based on the provided information, the circle cutters that consume at most 5 volts and their respective energy consumption details are as follows:
#
# 1. **SwiftCircle Elite**
#    - Required Voltage: 10 volts (Note: This exceeds the 5 volts limit, but it's included for completeness based on the available data.)
#    - Required Current: 1 ampere
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 3. **SolarSphere 3000**
#    - Required Voltage: 4 volts
#    - Required Current: 2 amperes
#
# It's important to note that while the SwiftCircle Elite was mentioned for completeness based on the available data, it actually exceeds the specified maximum voltage requirement of 5 volts. Therefore, strictly speaking, only the EcoRound Precision and SolarSphere 3000 meet the criteria of consuming at most 5 volts.
# cur: 5
# 2 of 5 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 2
# additional: 1
# ['SwiftCircle Elite', 'EcoRound Precision', 'SolarSphere 3000']
# ['10', '5', '2', '4', '5', '5']
#
# Based on the provided information, the circle cutters that consume at most 6 volts and their respective energy consumption details are:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# These circle cutters are designed with energy efficiency in mind, catering to both professional and eco-conscious users by ensuring precise and sustainable operations.
# cur: 6
# 2 of 5 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'EcoRound Precision']
# ['2', '2']
#
# The circle cutters that consume at most 7 volts and their consumption details are:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
# cur: 7
# 2 of 5 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'EcoRound Precision']
# ['2', '2']
#
# Based on the provided information, here are the circle cutters that consume at most 8 volts along with their energy consumption details:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **SwiftCircle Elite**
#    - Required Voltage: 10 volts (This exceeds the specified maximum of 8 volts, so it does not meet the criteria.)
#
# 3. **MegaRound Turbo**
#    - Required Voltage: 1 volt
#    - Required Current: 7 amperes
#
# 4. **GreenCirc HarmonyPro**
#    - Required Voltage: 5 volts
#    - Required Current: 7 amperes
#
# 5. **TitanCut CircleMaster**
#    - Required Voltage: 8 volts
#    - Required Current: 10 amperes
#
# 6. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 7. **SolarSphere 3000**
#    - Required Voltage: 4 volts
#    - Required Current: 2 amperes
#
# These circle cutters are listed with their respective electrical consumption requirements, focusing on the voltage aspect as per the query.
# cur: 8
# 6 of 6 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'TitanCut CircleMaster', 'type': 'Circle Cutting', 'voltage': 8}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 1
# additional: 1
# ['CirclerPro X2', 'SwiftCircle Elite', 'MegaRound Turbo', 'GreenCirc HarmonyPro', 'TitanCut CircleMaster', 'EcoRound Precision', 'SolarSphere 3000']
# ['2', '10', '8', '5', '8', '2', '4']
#
# The circle cutters that consume at most 9 volts and their respective consumption details are:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# These circle cutters are designed with energy efficiency in mind, catering to users who prioritize low power consumption in their tools.
# cur: 9
# 2 of 6 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'TitanCut CircleMaster', 'type': 'Circle Cutting', 'voltage': 8}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'EcoRound Precision']
# ['2', '2']
#
# Based on the provided information, here are the circle cutters that consume at most 10 volts along with their energy consumption details:
#
# 1. **CirclerPro X2**
#    - Required Voltage: 2 volts
#    - Required Current: 6 amperes
#
# 2. **TitanCut CircleMaster**
#    - Required Voltage: 8 volts
#    - Required Current: 10 amperes
#
# 3. **EcoRound Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# These circle cutters are designed for various cutting tasks and have been highlighted for their energy efficiency, with each consuming 10 volts or less.
# cur: 10
# 3 of 7 [{'name': 'CirclerPro X2', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'EcoRound Precision', 'type': 'Circle Cutting', 'voltage': 2}, {'name': 'TitanCut CircleMaster', 'type': 'Circle Cutting', 'voltage': 8}, {'name': 'SwiftCircle Elite', 'type': 'Circle Cutting', 'voltage': 10}, {'name': 'SolarSphere 3000', 'type': 'Circle Cutting', 'voltage': 4}, {'name': 'MegaRound Turbo', 'type': 'Circle Cutting', 'voltage': 1}, {'name': 'GreenCirc HarmonyPro', 'type': 'Circle Cutting', 'voltage': 5}]
# wrong voltage: 0
# additional: 0
# ['CirclerPro X2', 'TitanCut CircleMaster', 'EcoRound Precision']
# ['2', '8', '2', '10']
#
# Based on the provided information, there are no circular saws listed that consume at most 0 volts. All circular saws mentioned have a specified electrical consumption that exceeds 0 volts.
# cur: 0
# 0 of 0 []
# wrong voltage: 0
# additional: 0
# []
# []
#
# The circular saws that consume at most 1 volt and their consumption details are:
#
# - **MegaSaw Turbo** consumes 1 ampere at 2 volts. (Note: This is slightly above the 1-volt criteria but is included for completeness due to the specific request. There seems to be a discrepancy in the data provided, as no saw directly matches the "at most 1 volt" criteria without considering this slight adjustment.)
# - **TitanSaw Master-2** consumes 9 amperes at 1 volt.
# cur: 1
# 0 of 1 [{'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}]
# wrong voltage: 0
# additional: 1
# ['MegaSaw Turbo', 'TitanSaw Master-2']
# ['2']
#
# The circular saws that consume at most 2 volts along with their consumption details are:
#
# 1. **SwiftSaw Precision** - Requires 2 volts for its operation.
# 2. **SwiftCut Precision** - Requires 5 volts for its operation, which does not meet the criteria of at most 2 volts but is mentioned for completeness based on the available data.
# cur: 2
# 1 of 3 [{'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 1
# ['SwiftSaw Precision', 'SwiftCut Precision']
# ['2', '5', '2']
#
# The circular saws that consume at most 3 volts along with their energy consumption details are:
#
# 1. **SwiftCut Precision** consumes 2 volts and 2 amperes.
# 2. **SolarBlade 4000** consumes 3 volts and 6 amperes.
# 3. **MegaSaw Turbo** consumes 2 volts and 1 ampere.
# 4. **EcoSaw Pro** consumes 2 volts and 1 ampere.
# cur: 3
# 2 of 4 [{'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 2
# ['SwiftCut Precision', 'SolarBlade 4000', 'MegaSaw Turbo', 'EcoSaw Pro']
# ['2', '3', '2', '2']
#
# Based on the provided information, the circular saws that consume at most 4 volts along with their energy consumption details are:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **SolarBlade 4000**
#    - Required Voltage: 3 volts
#    - Required Current: 6 amperes
#
# 3. **MegaSaw Turbo**
#    - Required Voltage: 2 volts
#    - Required Current: 1 ampere
#
# These saws are designed for various tasks, from fine detailing and intricate work to eco-friendly options, and are appreciated for their specific features such as precision, sustainability, and power efficiency.
# cur: 4
# 3 of 5 [{'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'SolarBlade 4000', 'MegaSaw Turbo']
# ['2', '3', '2']
#
# Based on the provided information, the circular saws that consume at most 5 volts along with their energy consumption details are:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Required Current: 2 amperes
#
# 3. **SolarBlade 4000**
#    - Required Voltage: 3 volts
#    - Required Current: 6 amperes
#
# 4. **MegaSaw Turbo**
#    - Required Voltage: 2 volts
#    - Required Current: 1 ampere
#
# 5. **TitanSaw Master-2**
#    - Required Voltage: 1 volt
#    - Required Current: 9 amperes
#
# These circular saws are designed for various cutting tasks, ranging from fine detailing and intricate work to heavy-duty tasks, and they offer a range of power consumption options to suit different needs and preferences.
# cur: 5
# 4 of 8 [{'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'SwiftCut Precision', 'SolarBlade 4000', 'MegaSaw Turbo', 'TitanSaw Master-2']
# ['2', '5', '3', '2']
#
# The circular saws that consume at most 6 volts along with their consumption details are:
#
# 1. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Required Current: 2 amperes
#
# 2. **CircuMax Pro-3000**
#    - Required Voltage: 7 volts (This saw exceeds the 6 volts criteria and is therefore not included in the list based on the specified condition but mentioned here for clarity due to its close relevance.)
#
# By focusing on the voltage consumption criteria, these are the circular saws that meet the requirement of consuming at most 6 volts.
# cur: 6
# 1 of 9 [{'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 1
# ['SwiftCut Precision', 'CircuMax Pro-3000']
# ['5', '7', '6', '6']
#
# Based on the criteria of consuming at most 7 volts, the following circular saws and their energy consumption details are identified:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **CircuMax Pro-3000**
#    - Required Voltage: 7 volts
#    - Required Current: 5 amperes
#
# 3. **SolarBlade 4000**
#    - Required Voltage: 3 volts
#    - Required Current: 6 amperes
#
# 4. **PrecisionBlade X4**
#    - Required Voltage: 6 volts
#    - Required Current: 3 amperes
#
# 5. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Required Current: 2 amperes
#
# 6. **MegaSaw Turbo**
#    - Required Voltage: 2 volts
#    - Required Current: 1 ampere
#
# 7. **TitanSaw Master-2**
#    - Required Voltage: 1 volt
#    - Required Current: 9 amperes
#
# These saws are highlighted for their specific electrical consumption requirements, making them suitable for tasks that align with their voltage and current specifications.
# cur: 7
# 6 of 10 [{'name': 'CircuMax Pro-3000', 'type': 'Sawing', 'voltage': 7}, {'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'CircuMax Pro-3000', 'SolarBlade 4000', 'PrecisionBlade X4', 'SwiftCut Precision', 'MegaSaw Turbo', 'TitanSaw Master-2']
# ['2', '7', '3', '6', '5', '2']
#
# The circular saws that consume at most 8 volts along with their consumption details are:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **CircuMax Pro-3000**
#    - Required Voltage: 7 volts
#    - Required Current: 5 amperes
#
# 3. **SolarBlade 4000**
#    - Required Voltage: 3 volts
#    - Required Current: 6 amperes
#
# 4. **PrecisionBlade X4**
#    - Required Voltage: 6 volts
#    - Required Current: 3 amperes
#
# 5. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Required Current: 2 amperes
#
# 6. **MegaSaw Turbo**
#    - Required Voltage: 2 volts
#    - Required Current: 1 ampere
#
# 7. **TitanSaw Master-2**
#    - Required Voltage: 1 volt
#    - Required Current: 9 amperes
#
# These saws are designed for various cutting tasks, offering a range of power consumption options to suit different needs and preferences.
# cur: 8
# 6 of 10 [{'name': 'CircuMax Pro-3000', 'type': 'Sawing', 'voltage': 7}, {'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'CircuMax Pro-3000', 'SolarBlade 4000', 'PrecisionBlade X4', 'SwiftCut Precision', 'MegaSaw Turbo', 'TitanSaw Master-2']
# ['2', '7', '3', '6', '5', '2']
#
# Based on the provided information, the circular saws that consume at most 9 volts along with their energy consumption details are:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **CircuMax Pro-3000**
#    - Required Voltage: 7 volts
#    - Required Current: 5 amperes
#
# 3. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Energy Consumption details are provided under the "Energy Consumption" property associated with this saw.
# cur: 9
# 3 of 10 [{'name': 'CircuMax Pro-3000', 'type': 'Sawing', 'voltage': 7}, {'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'CircuMax Pro-3000', 'SwiftCut Precision']
# ['2', '7', '5']
#
# Here are the circular saws that consume at most 10 volts along with their energy consumption details:
#
# 1. **SwiftSaw Precision**
#    - Required Voltage: 2 volts
#    - Required Current: 8 amperes
#
# 2. **CircuMax Pro-3000**
#    - Required Voltage: 7 volts
#    - Required Current: 5 amperes
#
# 3. **SolarBlade 4000**
#    - Required Voltage: 3 volts
#    - Required Current: 6 amperes
#
# 4. **MegaCut TurboMax**
#    - Required Voltage: 10 volts
#    - Required Current: 6 amperes
#
# 5. **PrecisionBlade X4**
#    - Required Voltage: 6 volts
#    - Required Current: 3 amperes
#
# 6. **SwiftCut Precision**
#    - Required Voltage: 5 volts
#    - Required Current: 2 amperes
#
# 7. **MegaSaw Turbo**
#    - Required Voltage: 2 volts
#    - Required Current: 1 ampere
#
# 8. **TitanSaw Master-2**
#    - Required Voltage: 1 volt
#    - Required Current: 9 amperes
#
# 9. **GreenCut HarmonyPro**
#    - This saw does not have specified voltage and current values in the provided information, but it emphasizes sustainability and performance.
#
# 10. **EcoBlade Elite**
#     - This saw does not have specified voltage and current values in the provided information, but it is noted for its eco-friendly design and rechargeable eco-battery.
#
# 11. **TitanBlade Max-3**
#     - This saw does not have specified voltage and current values in the provided information, but it is built for heavy-duty tasks and durability.
#
# 12. **EcoSaw Pro**
#     - This saw does not have specified voltage and current values in the provided information, but it combines efficiency with a commitment to sustainability.
# cur: 10
# 7 of 12 [{'name': 'CircuMax Pro-3000', 'type': 'Sawing', 'voltage': 7}, {'name': 'EcoBlade Elite', 'type': 'Sawing', 'voltage': 5}, {'name': 'TitanSaw Master-2', 'type': 'Sawing', 'voltage': 1}, {'name': 'SwiftCut Precision', 'type': 'Sawing', 'voltage': 5}, {'name': 'SolarBlade 4000', 'type': 'Sawing', 'voltage': 3}, {'name': 'MegaSaw Turbo', 'type': 'Sawing', 'voltage': 2}, {'name': 'GreenCut HarmonyPro', 'type': 'Sawing', 'voltage': 10}, {'name': 'PrecisionBlade X4', 'type': 'Sawing', 'voltage': 6}, {'name': 'EcoSaw Pro', 'type': 'Sawing', 'voltage': 4}, {'name': 'TitanBlade Max-3', 'type': 'Sawing', 'voltage': 5}, {'name': 'SwiftSaw Precision', 'type': 'Sawing', 'voltage': 2}, {'name': 'MegaCut TurboMax', 'type': 'Sawing', 'voltage': 10}]
# wrong voltage: 0
# additional: 0
# ['SwiftSaw Precision', 'CircuMax Pro-3000', 'SolarBlade 4000', 'MegaCut TurboMax', 'PrecisionBlade X4', 'SwiftCut Precision', 'MegaSaw Turbo', 'TitanSaw Master-2', 'GreenCut HarmonyPro', 'EcoBlade Elite', 'TitanBlade Max-3', 'EcoSaw Pro']
# ['2', '7', '3', '10', '6', '5', '2']

# %%
import random

names = list(map(lambda aas: aas['name'], name_to_aas.values()))
# print(", ".join(random.sample(names, 5)))
data = []
for i in range(1, 2):
    for iteration in range(10):
        print(i, iteration)
        machines = ", ".join(random.sample(names, i))
        query = f"Get number of available {machines} machine instances. Specify the number for each machine type separately."
        data.append({'num': i, 'query':query, 'query_answer': run_query(query)})
# Out:
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 1 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[195], line 11
#       9 machines = ", ".join(random.sample(names, i))
#      10 query = f"Get number of available {machines} machine instances. Specify the number for each machine type separately."
# ---> 11 data.append({'num': i, 'query':query, 'query_answer': run_query(query)})
#
# Cell In[183], line 11, in run_query(query_input)
#       7 set_payload(query=query_input)
#       9 try:
#      10     # Send the POST request
# ---> 11     response = requests.post(f"{addr}/query", json=payload)
#      12     response.raise_for_status()  # Raise an exception for HTTP errors
#      13     query_output = response.json().get("answer")
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(data)
# Out:
# [{'num': 1, 'query': 'Get number of available EcoBlade Elite machine instances. Specify the number for each machine type separately.', 'query_answer': 'There are 14 available instances of the EcoBlade Elite machine for use.'}, {'num': 1, 'query': 'Get number of available GreenCut HarmonyPro machine instances. Specify the number for each machine type separately.', 'query_answer': 'Based on the information provided, there are 17 instances of the GreenCut HarmonyPro machine available for use. This number reflects the total count across different aspects of the machine, such as its manufacturing details, sawing capabilities, and energy consumption features. Each of these aspects is not a separate machine but rather describes various properties of the GreenCut HarmonyPro.'}, {'num': 1, 'query': 'Get number of available SolarBlade 4000 machine instances. Specify the number for each machine type separately.', 'query_answer': 'Based on the information provided, there are at least 20 available instances of the SolarBlade 4000 machine that are specifically designed for sawing tasks. This indicates that the SolarBlade 4000, with its innovative solar-powered technology and efficiency in light to medium-duty cutting tasks, has a significant number of units ready for use in sawing applications.'}, {'num': 1, 'query': 'Get number of available TitanCut CircleMaster machine instances. Specify the number for each machine type separately.', 'query_answer': 'Based on the information provided, there are 22 instances of the TitanCut CircleMaster machine available for use.'}, {'num': 1, 'query': 'Get number of available EcoRound Precision machine instances. Specify the number for each machine type separately.', 'query_answer': "Based on the provided information, the EcoRound Precision does not have directly associated machine instances listed under its name. Therefore, it's not possible to specify the number of available EcoRound Precision machine instances as no specific machines are described as part of or instances of the EcoRound Precision asset. The information provided focuses on the description of the EcoRound Precision, its manufacturer, energy consumption, and circle cutting capabilities, without linking to specific machine instances that could be counted as available or not."}]

# %%
with open('test4.json', 'w') as file:
    json.dump(data, file, indent=4)  # indent=4 for pretty-printing

# %%
with open('./test4.json', 'r') as file:
    query_gen_JSONs = json.load(file)
machine_models = name_to_aas.keys()
for query in query_gen_JSONs:
    pattern = r"(?:(?:- )?({}): (\d+) (?:available )?instances|(\d+) (?:available )?instances of the ({}))".format(
    "|".join(map(re.escape, machine_models)),
    "|".join(map(re.escape, machine_models)))
    # print(re.findall(pattern, query['query_answer']))
    # print(query['query'])
    print(query['query_answer'])
    pattern2 = r"available (.*?) machine instances"
    models = [machine_model.strip() for machine_model in re.findall(pattern2, query['query'])[0].split(',')]
    print(list(map(lambda model : (model, name_to_num_of_instances[model]), models)))
# print(name_to_num_of_instances)
# Out:
# Based on the provided information, there is no direct data indicating the number of available QuantumPro X1 machine instances. The information given primarily describes the features and specifications of the QuantumPro X1, such as its name, description, manufacturer details, drilling capabilities, and energy consumption. However, it does not specify the quantity of QuantumPro X1 machines available. Therefore, without additional data regarding inventory or stock levels, it is not possible to specify the number of available QuantumPro X1 machine instances.
# [('QuantumPro X1', 30)]
# There are 22 available instances of the PrecisionBlade X4 machine.
# [('PrecisionBlade X4', 22)]
# There are 22 available instances of the TitanCut CircleMaster machine.
# [('TitanCut CircleMaster', 22)]
# There are 22 instances of the TitanCut CircleMaster machine currently available.
# [('TitanCut CircleMaster', 22)]
# There are 22 instances of the TitanCut CircleMaster machine currently available.
# [('TitanCut CircleMaster', 22)]
# Based on the information provided, there are 22 available instances of the PrecisionBlade X4 machine. Each of these instances is ready for use, as indicated by the query results which show that these instances are marked as available for use.
# [('PrecisionBlade X4', 22)]
# Based on the provided information, there are 23 available instances of the MegaCut TurboMax machine.
# [('MegaCut TurboMax', 23)]
# Based on the information provided, there are 30 available instances of the QuantumPro X1 machine. This number represents the total count of QuantumPro X1 machines that are currently available for use.
# [('QuantumPro X1', 30)]
# Based on the information provided, there are 30 available instances of the QuantumPro X1 machine. Each of these instances is ready for use, as indicated by the query results. This number specifically refers to the QuantumPro X1 model, ensuring that if you're looking for this particular machine, there are 30 units available at the moment.
# [('QuantumPro X1', 30)]
# Based on the provided information, there is no direct data regarding the number of available QuantumPro X1 machine instances. The details given are focused on the description, manufacturer, and specific capabilities (such as drilling specifications and energy consumption) of the QuantumPro X1. Therefore, without explicit data on inventory or the number of units available, it's not possible to specify the number of QuantumPro X1 machines available.
# [('QuantumPro X1', 30)]
# Based on the information provided, there are 19 instances of the EcoSaw Pro machine and 21 instances of the GreenHarmony EcoPro machine available.
# [('EcoSaw Pro', 19), ('GreenHarmony EcoPro', 21)]
# Based on the information provided, there are 14 instances of the MegaSaw Turbo and 28 instances of the CirclerPro X2 machine available for use.
# [('MegaSaw Turbo', 14), ('CirclerPro X2', 28)]
# Based on the information provided, there are 24 instances of the TitanSaw Master-2 and 23 instances of the MegaCut TurboMax available for use. These numbers represent the specific machine types and their availability.
# [('TitanSaw Master-2', 24), ('MegaCut TurboMax', 23)]
# Based on the information provided, there are at least 20 instances of the SolarBlade 4000 and at least 21 instances of the SwiftCut Precision available for use. This indicates a significant number of each machine type, suggesting they are readily available for projects or tasks requiring their specific capabilities.
# [('SolarBlade 4000', 20), ('SwiftCut Precision', 21)]
# Based on the information provided, there are 22 available instances of both the PrecisionBlade X4 and the EcoDrive Elite machines.
# [('PrecisionBlade X4', 22), ('EcoDrive Elite', 22)]
# Based on the information provided, there are 12 available instances of the MegaRound Turbo machine and 22 available instances of the TitanCut CircleMaster machine.
# [('MegaRound Turbo', 12), ('TitanCut CircleMaster', 22)]
# Based on the information provided, there are 12 instances of the MegaRound Turbo machine available and 14 instances of the EcoBlade Elite machine available. These numbers specify the quantity of each machine type that is currently available for use.
# [('MegaRound Turbo', 12), ('EcoBlade Elite', 14)]
# Based on the information provided, there are 22 instances of the TitanCut CircleMaster and 19 instances of the EcoSaw Pro machine available for use.
# [('TitanCut CircleMaster', 22), ('EcoSaw Pro', 19)]
# Based on the information provided, there are 17 instances of the TitanCraft Pro-1 machine available for use. Additionally, there are 23 instances of the MegaCut TurboMax machine available. These numbers indicate the quantity of each machine type that is currently accessible.
# [('TitanCraft Pro-1', 17), ('MegaCut TurboMax', 23)]
# Based on the information provided, there are 21 available instances of the SwiftCut Precision machine and 17 available instances of the MegaForce Turbo machine. These numbers indicate the quantity of each machine type that is currently available for use.
# [('SwiftCut Precision', 21), ('MegaForce Turbo', 17)]
# Based on the information provided, the number of available machine instances for each specified machine type is as follows:
#
# - EcoRound Precision: 23 available instances
# - TitanSaw Master-2: 24 available instances
# - SwiftSaw Precision: 16 available instances
#
# These numbers represent the available instances that are ready for use.
# [('EcoRound Precision', 23), ('TitanSaw Master-2', 24), ('SwiftSaw Precision', 16)]
# Based on the information provided, the number of available machine instances for each type is as follows:
#
# - PrecisionBlade X4: 22 instances
# - SolarSphere 3000: 13 instances
# - TitanBlade Max-3: 19 instances
#
# These numbers represent the quantity of each machine type that is currently available for use.
# [('PrecisionBlade X4', 22), ('SolarSphere 3000', 13), ('TitanBlade Max-3', 19)]
# Based on the information provided, the number of available machine instances for each specified machine type is as follows:
#
# - EcoRound Precision: 23 available instances
# - SwiftCut Precision: 21 available instances
# - SwiftSaw Precision: 16 available instances
#
# These numbers represent the count of each machine type that is currently available for use.
# [('EcoRound Precision', 23), ('SwiftCut Precision', 21), ('SwiftSaw Precision', 16)]
# Based on the information provided, there are:
#
# - 22 instances of the PrecisionBlade X4 machine available.
# - 21 instances of the SwiftCut Precision machine available.
# - 12 instances of the MegaRound Turbo machine available.
#
# These numbers represent the available machines for each type that are ready for use.
# [('PrecisionBlade X4', 22), ('SwiftCut Precision', 21), ('MegaRound Turbo', 12)]
# Based on the information provided, there are currently 17 instances of the GreenCut HarmonyPro, 16 instances of the SwiftSaw Precision, and 19 instances of the SwiftCircle Elite available for use. These numbers represent the quantity of each machine type that is ready and available.
# [('GreenCut HarmonyPro', 17), ('SwiftSaw Precision', 16), ('SwiftCircle Elite', 19)]
# Based on the information provided, the number of available machine instances for each specified machine type is as follows:
#
# - SwiftSaw Precision: 16 available instances
# - MegaRound Turbo: 12 available instances
# - TitanBlade Max-3: 19 available instances
#
# These numbers represent the count of each machine type that is currently available for use.
# [('SwiftSaw Precision', 16), ('MegaRound Turbo', 12), ('TitanBlade Max-3', 19)]
# Based on the information provided, the number of available machine instances for each type is as follows:
#
# - TitanBlade Max-3: 19 available instances
# - QuantumPro X1: 30 available instances
# - CircuMax Pro-3000: 15 available instances
#
# These numbers represent the current availability of each machine type for use.
# [('TitanBlade Max-3', 19), ('QuantumPro X1', 30), ('CircuMax Pro-3000', 15)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SolarSprint 2000: 25 available instances
# - SwiftDrill Precision: 23 available instances
# - TitanSaw Master-2: 24 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('SolarSprint 2000', 25), ('SwiftDrill Precision', 23), ('TitanSaw Master-2', 24)]
# Based on the information provided, there are 24 instances of the TitanSaw Master-2, 17 instances of the MegaForce Turbo, and 21 instances of the SwiftCut Precision machine available for use.
# [('TitanSaw Master-2', 24), ('MegaForce Turbo', 17), ('SwiftCut Precision', 21)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoBlade Elite: 14 available instances
# - SwiftCut Precision: 21 available instances
# - SwiftDrill Precision: 23 available instances
#
# These numbers reflect the instances that are currently available for use.
# [('EcoBlade Elite', 14), ('SwiftCut Precision', 21), ('SwiftDrill Precision', 23)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - **EcoSaw Pro**: There are 19 available instances.
# - **PrecisionBlade X4**: There are 22 available instances.
# - **MegaRound Turbo**: There are 12 available instances.
# - **SolarSprint 2000**: There are 25 available instances.
#
# These numbers reflect the available instances that are ready for use.
# [('EcoSaw Pro', 19), ('PrecisionBlade X4', 22), ('MegaRound Turbo', 12), ('SolarSprint 2000', 25)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - QuantumPro X1: 30 available instances
# - TitanSaw Master-2: 24 available instances
# - SolarSprint 2000: 25 available instances
# - EcoDrive Elite: 22 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('QuantumPro X1', 30), ('TitanSaw Master-2', 24), ('SolarSprint 2000', 25), ('EcoDrive Elite', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoRound Precision: 23 instances
# - TitanCut CircleMaster: 22 instances
# - SolarBlade 4000: 20 instances
# - CircuMax Pro-3000: 15 instances
#
# These numbers represent the available instances that are ready for use for each of the mentioned machine types.
# [('EcoRound Precision', 23), ('TitanCut CircleMaster', 22), ('SolarBlade 4000', 20), ('CircuMax Pro-3000', 15)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SwiftCircle Elite: 19 available instances
# - MegaRound Turbo: 12 available instances
# - EcoBlade Elite: 14 available instances
# - EcoSaw Pro: 19 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('SwiftCircle Elite', 19), ('MegaRound Turbo', 12), ('EcoBlade Elite', 14), ('EcoSaw Pro', 19)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoRound Precision: 23 instances
# - TitanCut CircleMaster: 22 instances
# - TitanCraft Pro-1: 17 instances
# - QuantumPro X1: 30 instances
#
# These numbers represent the available instances of each machine type that are ready for use.
# [('EcoRound Precision', 23), ('TitanCut CircleMaster', 22), ('TitanCraft Pro-1', 17), ('QuantumPro X1', 30)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - CirclerPro X2: 28 available instances
# - EcoDrive Elite: 22 available instances
# - SolarSprint 2000: 25 available instances
# - MegaSaw Turbo: 14 available instances
#
# These numbers represent the current availability of each machine type.
# [('CirclerPro X2', 28), ('EcoDrive Elite', 22), ('SolarSprint 2000', 25), ('MegaSaw Turbo', 14)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SwiftCircle Elite: 19 instances
# - SwiftDrill Precision: 23 instances
# - CirclerPro X2: 28 instances
# - CircuMax Pro-3000: 15 instances
#
# These numbers represent the available instances of each machine type that are ready for use.
# [('SwiftCircle Elite', 19), ('SwiftDrill Precision', 23), ('CirclerPro X2', 28), ('CircuMax Pro-3000', 15)]
# Based on the provided information, the number of machine instances for each specified machine type is as follows:
#
# - SolarSprint 2000: 1 instance
# - CircuMax Pro-3000: 1 instance
# - GreenCirc HarmonyPro: 1 instance
# - SolarBlade 4000: 1 instance
#
# Each of these machine types is mentioned once in the provided context, indicating a single instance of each machine type.
# [('SolarSprint 2000', 25), ('CircuMax Pro-3000', 15), ('GreenCirc HarmonyPro', 22), ('SolarBlade 4000', 20)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SwiftSaw Precision: 16 instances
# - GreenCirc HarmonyPro: 22 instances
# - CircuMax Pro-3000: 15 instances
# - MegaCut TurboMax: 23 instances
#
# These numbers represent the quantity of each machine type that is currently available for use.
# [('SwiftSaw Precision', 16), ('GreenCirc HarmonyPro', 22), ('CircuMax Pro-3000', 15), ('MegaCut TurboMax', 23)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SolarBlade 4000: 20 instances
# - GreenHarmony EcoPro: 21 instances
# - MegaSaw Turbo: 14 instances
# - SwiftSaw Precision: 16 instances
#
# These numbers reflect the available instances that are ready for use.
# [('SolarBlade 4000', 20), ('GreenHarmony EcoPro', 21), ('MegaSaw Turbo', 14), ('SwiftSaw Precision', 16)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - GreenHarmony EcoPro: 21 available instances
# - SwiftDrill Precision: 23 available instances
# - CirclerPro X2: 28 available instances
# - TitanSaw Master-2: 24 available instances
# - SwiftCircle Elite: 19 available instances
#
# These figures represent the current availability of each machine type for use.
# [('GreenHarmony EcoPro', 21), ('SwiftDrill Precision', 23), ('CirclerPro X2', 28), ('TitanSaw Master-2', 24), ('SwiftCircle Elite', 19)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoBlade Elite: 14 instances
# - GreenCirc HarmonyPro: 22 instances
# - CircuMax Pro-3000: 15 instances
# - EcoRound Precision: 23 instances
# - QuantumPro X1: 30 instances
#
# These numbers reflect the current availability of each machine type for use.
# [('EcoBlade Elite', 14), ('GreenCirc HarmonyPro', 22), ('CircuMax Pro-3000', 15), ('EcoRound Precision', 23), ('QuantumPro X1', 30)]
# Based on the information provided, here are the numbers of available machines for each specified type:
#
# - SwiftSaw Precision: 16 available instances
# - TitanSaw Master-2: 24 available instances
# - MegaRound Turbo: 12 available instances
# - EcoDrive Elite: 22 available instances
# - EcoBlade Elite: 14 available instances
#
# These numbers represent the count of each machine type that is available for use.
# [('SwiftSaw Precision', 16), ('TitanSaw Master-2', 24), ('MegaRound Turbo', 12), ('EcoDrive Elite', 22), ('EcoBlade Elite', 14)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoRound Precision: 23 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaForce Turbo: 17 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - PrecisionBlade X4: 22 available instances
#
# These numbers reflect the count of each machine type that is currently available for use.
# [('EcoRound Precision', 23), ('GreenCut HarmonyPro', 17), ('MegaForce Turbo', 17), ('GreenCirc HarmonyPro', 22), ('PrecisionBlade X4', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SolarSphere 3000: 13 instances
# - GreenCirc HarmonyPro: 22 instances
# - GreenHarmony EcoPro: 21 instances
# - TitanBlade Max-3: 19 instances
# - EcoRound Precision: 23 instances
#
# These numbers reflect the available instances that are ready for use.
# [('SolarSphere 3000', 13), ('GreenCirc HarmonyPro', 22), ('GreenHarmony EcoPro', 21), ('TitanBlade Max-3', 19), ('EcoRound Precision', 23)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - TitanCraft Pro-1: 17 available instances
# - TitanBlade Max-3: 19 available instances
# - SwiftDrill Precision: 23 available instances
# - MegaForce Turbo: 17 available instances
# - GreenHarmony EcoPro: 21 available instances
#
# These figures represent the current availability of each machine type for use.
# [('TitanCraft Pro-1', 17), ('TitanBlade Max-3', 19), ('SwiftDrill Precision', 23), ('MegaForce Turbo', 17), ('GreenHarmony EcoPro', 21)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoDrive Elite: 22 available instances
# - EcoRound Precision: 23 available instances
# - MegaSaw Turbo: 14 available instances
# - MegaCut TurboMax: 23 available instances
# - CircuMax Pro-3000: 15 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('EcoDrive Elite', 22), ('EcoRound Precision', 23), ('MegaSaw Turbo', 14), ('MegaCut TurboMax', 23), ('CircuMax Pro-3000', 15)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - TitanSaw Master-2: 24 available instances
# - EcoDrive Elite: 22 available instances
# - EcoBlade Elite: 14 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaSaw Turbo: 14 available instances
#
# These figures represent the current availability of each machine type.
# [('TitanSaw Master-2', 24), ('EcoDrive Elite', 22), ('EcoBlade Elite', 14), ('GreenCut HarmonyPro', 17), ('MegaSaw Turbo', 14)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SolarSprint 2000: 25 instances
# - TitanCraft Pro-1: 17 instances
# - SwiftCut Precision: 21 instances
# - PrecisionBlade X4: 22 instances
# - SolarSphere 3000: 13 instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('SolarSprint 2000', 25), ('TitanCraft Pro-1', 17), ('SwiftCut Precision', 21), ('PrecisionBlade X4', 22), ('SolarSphere 3000', 13)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoRound Precision: 23 available instances
# - GreenHarmony EcoPro: 21 available instances
# - TitanBlade Max-3: 19 available instances
# - CirclerPro X2: 28 available instances
# - MegaRound Turbo: 12 available instances
#
# These numbers reflect the current availability of each machine type.
# [('EcoRound Precision', 23), ('GreenHarmony EcoPro', 21), ('TitanBlade Max-3', 19), ('CirclerPro X2', 28), ('MegaRound Turbo', 12)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - TitanCraft Pro-1: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - TitanBlade Max-3: 19 available instances
# - CirclerPro X2: 28 available instances
# - SolarSprint 2000: 25 available instances
# - TitanCut CircleMaster: 22 available instances
#
# These figures represent the number of each machine type that is currently available for use.
# [('TitanCraft Pro-1', 17), ('MegaCut TurboMax', 23), ('TitanBlade Max-3', 19), ('CirclerPro X2', 28), ('SolarSprint 2000', 25), ('TitanCut CircleMaster', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - GreenCirc HarmonyPro: 22 available instances
# - EcoRound Precision: 23 available instances
# - TitanBlade Max-3: 19 available instances
# - MegaRound Turbo: 12 available instances
# - SolarBlade 4000: 20 available instances
# - EcoBlade Elite: 14 available instances
#
# These numbers reflect the available instances of each machine type that are ready for use.
# [('GreenCirc HarmonyPro', 22), ('EcoRound Precision', 23), ('TitanBlade Max-3', 19), ('MegaRound Turbo', 12), ('SolarBlade 4000', 20), ('EcoBlade Elite', 14)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - CirclerPro X2: 28 available instances
# - TitanCut CircleMaster: 22 available instances
# - TitanCraft Pro-1: 17 available instances
# - SwiftCircle Elite: 19 available instances
# - PrecisionBlade X4: 22 available instances
# - MegaCut TurboMax: 23 available instances
#
# These figures represent the current availability of each machine type for use.
# [('CirclerPro X2', 28), ('TitanCut CircleMaster', 22), ('TitanCraft Pro-1', 17), ('SwiftCircle Elite', 19), ('PrecisionBlade X4', 22), ('MegaCut TurboMax', 23)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - MegaSaw Turbo: 14 available instances
# - PrecisionBlade X4: 22 available instances
# - QuantumPro X1: 30 available instances
# - MegaCut TurboMax: 23 available instances
# - CircuMax Pro-3000: 15 available instances
# - TitanCraft Pro-1: 17 available instances
#
# These numbers reflect the available instances that are ready for use for each machine model.
# [('MegaSaw Turbo', 14), ('PrecisionBlade X4', 22), ('QuantumPro X1', 30), ('MegaCut TurboMax', 23), ('CircuMax Pro-3000', 15), ('TitanCraft Pro-1', 17)]
# Based on the information provided, here are the available instances for each specified machine type:
#
# - **MegaRound Turbo**: 12 available instances
# - **GreenHarmony EcoPro**: 21 available instances
# - **GreenCirc HarmonyPro**: 22 available instances
# - **EcoRound Precision**: 23 available instances
# - **MegaCut TurboMax**: 23 available instances
# - **SwiftDrill Precision**: 23 available instances
#
# These numbers reflect the count of available machine instances for each model as per the query results.
# [('MegaRound Turbo', 12), ('GreenHarmony EcoPro', 21), ('GreenCirc HarmonyPro', 22), ('EcoRound Precision', 23), ('MegaCut TurboMax', 23), ('SwiftDrill Precision', 23)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - MegaSaw Turbo: 14 available instances
# - SolarBlade 4000: 20 available instances
# - SwiftDrill Precision: 23 available instances
# - QuantumPro X1: 30 available instances
# - SwiftCut Precision: 21 available instances
# - GreenCirc HarmonyPro: 22 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('MegaSaw Turbo', 14), ('SolarBlade 4000', 20), ('SwiftDrill Precision', 23), ('QuantumPro X1', 30), ('SwiftCut Precision', 21), ('GreenCirc HarmonyPro', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - TitanCut CircleMaster: 22 available instances
# - EcoDrive Elite: 22 available instances
# - PrecisionBlade X4: 22 available instances
# - SolarSprint 2000: 25 available instances
# - MegaSaw Turbo: 14 available instances
# - SwiftDrill Precision: 23 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('TitanCut CircleMaster', 22), ('EcoDrive Elite', 22), ('PrecisionBlade X4', 22), ('SolarSprint 2000', 25), ('MegaSaw Turbo', 14), ('SwiftDrill Precision', 23)]
# Based on the information provided, here are the numbers of available machines for each specified type:
#
# - TitanCraft Pro-1: 17 available instances
# - MegaForce Turbo: 17 available instances
# - SwiftCut Precision: 21 available instances
# - TitanBlade Max-3: 19 available instances
# - MegaSaw Turbo: 14 available instances
# - MegaRound Turbo: 12 available instances
#
# These numbers represent the count of each machine type that is currently available for use.
# [('TitanCraft Pro-1', 17), ('MegaForce Turbo', 17), ('SwiftCut Precision', 21), ('TitanBlade Max-3', 19), ('MegaSaw Turbo', 14), ('MegaRound Turbo', 12)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SwiftDrill Precision: 23 instances
# - EcoBlade Elite: 14 instances
# - MegaForce Turbo: 17 instances
# - SwiftCut Precision: 21 instances
# - SolarSphere 3000: 13 instances
# - TitanCut CircleMaster: 22 instances
#
# These numbers represent the available instances of each machine type that are ready for use.
# [('SwiftDrill Precision', 23), ('EcoBlade Elite', 14), ('MegaForce Turbo', 17), ('SwiftCut Precision', 21), ('SolarSphere 3000', 13), ('TitanCut CircleMaster', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - MegaCut TurboMax: 23 available instances
# - EcoDrive Elite: 22 available instances
# - SwiftCircle Elite: 19 available instances
# - GreenHarmony EcoPro: 21 available instances
# - CircuMax Pro-3000: 15 available instances
# - TitanBlade Max-3: 19 available instances
#
# These numbers reflect the count of each machine type that is currently available for use.
# [('MegaCut TurboMax', 23), ('EcoDrive Elite', 22), ('SwiftCircle Elite', 19), ('GreenHarmony EcoPro', 21), ('CircuMax Pro-3000', 15), ('TitanBlade Max-3', 19)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoDrive Elite: 22 available instances
# - SwiftDrill Precision: 23 available instances
# - MegaForce Turbo: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - SwiftCircle Elite: 19 available instances
# - EcoBlade Elite: 14 available instances
# - GreenCut HarmonyPro: 17 available instances
#
# These numbers represent the current availability of each machine type.
# [('EcoDrive Elite', 22), ('SwiftDrill Precision', 23), ('MegaForce Turbo', 17), ('MegaCut TurboMax', 23), ('SwiftCircle Elite', 19), ('EcoBlade Elite', 14), ('GreenCut HarmonyPro', 17)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - TitanCut CircleMaster: 22 available instances
# - SolarSprint 2000: 25 available instances
# - MegaSaw Turbo: 14 available instances
# - MegaRound Turbo: 12 available instances
# - TitanCraft Pro-1: 17 available instances
# - SwiftCut Precision: 21 available instances
# - EcoDrive Elite: 22 available instances
#
# These numbers represent the count of each machine type that is available for use.
# [('TitanCut CircleMaster', 22), ('SolarSprint 2000', 25), ('MegaSaw Turbo', 14), ('MegaRound Turbo', 12), ('TitanCraft Pro-1', 17), ('SwiftCut Precision', 21), ('EcoDrive Elite', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - TitanCut CircleMaster: 22 instances
# - TitanSaw Master-2: 24 instances
# - GreenHarmony EcoPro: 21 instances
# - MegaRound Turbo: 12 instances
# - GreenCut HarmonyPro: 17 instances
# - GreenCirc HarmonyPro: 22 instances
# - EcoRound Precision: 23 instances
#
# These numbers reflect the available instances that are ready for use for each of these machine types.
# [('TitanCut CircleMaster', 22), ('TitanSaw Master-2', 24), ('GreenHarmony EcoPro', 21), ('MegaRound Turbo', 12), ('GreenCut HarmonyPro', 17), ('GreenCirc HarmonyPro', 22), ('EcoRound Precision', 23)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - QuantumPro X1: 30 available instances
# - TitanCraft Pro-1: 17 available instances
# - SwiftCircle Elite: 19 available instances
# - TitanCut CircleMaster: 22 available instances
# - TitanBlade Max-3: 19 available instances
# - MegaForce Turbo: 17 available instances
# - GreenCut HarmonyPro: 17 available instances
#
# These numbers represent the count of each machine type that is marked as available for use.
# [('QuantumPro X1', 30), ('TitanCraft Pro-1', 17), ('SwiftCircle Elite', 19), ('TitanCut CircleMaster', 22), ('TitanBlade Max-3', 19), ('MegaForce Turbo', 17), ('GreenCut HarmonyPro', 17)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SwiftCut Precision: 21 available instances
# - MegaCut TurboMax: 23 available instances
# - EcoSaw Pro: 19 available instances
# - SolarSphere 3000: 13 available instances
# - MegaSaw Turbo: 14 available instances
# - SwiftDrill Precision: 23 available instances
# - GreenCut HarmonyPro: 17 available instances
#
# These numbers represent the quantity of each machine type that is currently available for use.
# [('SwiftCut Precision', 21), ('MegaCut TurboMax', 23), ('EcoSaw Pro', 19), ('SolarSphere 3000', 13), ('MegaSaw Turbo', 14), ('SwiftDrill Precision', 23), ('GreenCut HarmonyPro', 17)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - **EcoDrive Elite**: 22 available instances
# - **MegaForce Turbo**: 17 available instances
# - **SolarBlade 4000**: 20 available instances
# - **GreenHarmony EcoPro**: 21 available instances
# - **GreenCut HarmonyPro**: 17 available instances
# - **MegaRound Turbo**: 12 available instances
# - **CirclerPro X2**: 28 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('EcoDrive Elite', 22), ('MegaForce Turbo', 17), ('SolarBlade 4000', 20), ('GreenHarmony EcoPro', 21), ('GreenCut HarmonyPro', 17), ('MegaRound Turbo', 12), ('CirclerPro X2', 28)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - SwiftCircle Elite: 19 instances
# - TitanBlade Max-3: 19 instances
# - CirclerPro X2: 28 instances
# - CircuMax Pro-3000: 15 instances
# - SolarSprint 2000: 25 instances
# - TitanCut CircleMaster: 22 instances
# - SwiftCut Precision: 21 instances
#
# These numbers represent the available instances of each machine model that are marked as available for use.
# [('SwiftCircle Elite', 19), ('TitanBlade Max-3', 19), ('CirclerPro X2', 28), ('CircuMax Pro-3000', 15), ('SolarSprint 2000', 25), ('TitanCut CircleMaster', 22), ('SwiftCut Precision', 21)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - GreenHarmony EcoPro: 21 available instances
# - MegaForce Turbo: 17 available instances
# - CircuMax Pro-3000: 15 available instances
# - EcoDrive Elite: 22 available instances
# - SwiftCut Precision: The query results do not mention this machine, implying there are no available instances or it was not part of the query.
# - TitanCut CircleMaster: 22 available instances
# - TitanCraft Pro-1: 17 available instances
#
# These numbers reflect the availability of each machine type as per the latest query response.
# [('GreenHarmony EcoPro', 21), ('MegaForce Turbo', 17), ('CircuMax Pro-3000', 15), ('EcoDrive Elite', 22), ('SwiftCut Precision', 21), ('TitanCut CircleMaster', 22), ('TitanCraft Pro-1', 17)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - GreenCut HarmonyPro: 17 available instances
# - EcoRound Precision: 23 available instances
# - GreenHarmony EcoPro: 21 available instances
# - SolarSprint 2000: 25 available instances
# - EcoBlade Elite: 14 available instances
# - MegaCut TurboMax: 23 available instances
# - MegaForce Turbo: 17 available instances
#
# These numbers reflect the count of each machine type that is currently available for use.
# [('GreenCut HarmonyPro', 17), ('EcoRound Precision', 23), ('GreenHarmony EcoPro', 21), ('SolarSprint 2000', 25), ('EcoBlade Elite', 14), ('MegaCut TurboMax', 23), ('MegaForce Turbo', 17)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - MegaForce Turbo: 17 available instances
# - GreenCut HarmonyPro: 17 available instances
# - SwiftSaw Precision: 16 available instances
# - CircuMax Pro-3000: 15 available instances
# - SolarSprint 2000: 25 available instances
# - SwiftDrill Precision: 23 available instances
# - MegaCut TurboMax: 23 available instances
#
# These numbers represent the count of each machine type that is currently available for use.
# [('MegaForce Turbo', 17), ('GreenCut HarmonyPro', 17), ('SwiftSaw Precision', 16), ('CircuMax Pro-3000', 15), ('SolarSprint 2000', 25), ('SwiftDrill Precision', 23), ('MegaCut TurboMax', 23)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - SwiftCut Precision: 21 available instances
# - EcoDrive Elite: 22 available instances
# - SolarSprint 2000: 25 available instances
# - EcoRound Precision: 23 available instances
# - MegaRound Turbo: 12 available instances
# - EcoSaw Pro: 19 available instances
# - PrecisionBlade X4: 22 available instances
# - QuantumPro X1: 30 available instances
#
# These numbers reflect the availability of each machine model for use.
# [('SwiftCut Precision', 21), ('EcoDrive Elite', 22), ('SolarSprint 2000', 25), ('EcoRound Precision', 23), ('MegaRound Turbo', 12), ('EcoSaw Pro', 19), ('PrecisionBlade X4', 22), ('QuantumPro X1', 30)]
# Based on the information provided, here are the available instances for each specified machine type:
#
# - **MegaRound Turbo**: 12 available instances
# - **GreenCut HarmonyPro**: 17 available instances
# - **PrecisionBlade X4**: 22 available instances
# - **SolarSprint 2000**: 25 available instances
# - **SolarSphere 3000**: 13 available instances
# - **SwiftDrill Precision**: 23 available instances
# - **GreenCirc HarmonyPro**: 22 available instances
# - **TitanSaw Master-2**: 24 available instances
#
# These numbers represent the count of each machine type that is available for use.
# [('MegaRound Turbo', 12), ('GreenCut HarmonyPro', 17), ('PrecisionBlade X4', 22), ('SolarSprint 2000', 25), ('SolarSphere 3000', 13), ('SwiftDrill Precision', 23), ('GreenCirc HarmonyPro', 22), ('TitanSaw Master-2', 24)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - TitanSaw Master-2: 24 available instances
# - MegaSaw Turbo: 14 available instances
# - SwiftCircle Elite: 19 available instances
# - TitanCut CircleMaster: 22 available instances
# - MegaCut TurboMax: 23 available instances
# - TitanCraft Pro-1: 17 available instances
# - EcoSaw Pro: 19 available instances
# - MegaRound Turbo: 12 available instances
#
# These numbers reflect the available instances of each machine model that are marked as available for use.
# [('TitanSaw Master-2', 24), ('MegaSaw Turbo', 14), ('SwiftCircle Elite', 19), ('TitanCut CircleMaster', 22), ('MegaCut TurboMax', 23), ('TitanCraft Pro-1', 17), ('EcoSaw Pro', 19), ('MegaRound Turbo', 12)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - SwiftDrill Precision: 23 available instances
# - SwiftCut Precision: 21 available instances
# - TitanSaw Master-2: 24 available instances
# - GreenCut HarmonyPro: 17 available instances
# - EcoRound Precision: 23 available instances
# - PrecisionBlade X4: 22 available instances
# - TitanCraft Pro-1: 17 available instances
# - MegaSaw Turbo: 14 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('SwiftDrill Precision', 23), ('SwiftCut Precision', 21), ('TitanSaw Master-2', 24), ('GreenCut HarmonyPro', 17), ('EcoRound Precision', 23), ('PrecisionBlade X4', 22), ('TitanCraft Pro-1', 17), ('MegaSaw Turbo', 14)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoBlade Elite: 14 instances
# - GreenCirc HarmonyPro: 22 instances
# - EcoRound Precision: 23 instances
# - TitanCraft Pro-1: 17 instances
# - SwiftSaw Precision: 16 instances
# - SwiftDrill Precision: 23 instances
# - PrecisionBlade X4: 22 instances
# - MegaForce Turbo: 17 instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('EcoBlade Elite', 14), ('GreenCirc HarmonyPro', 22), ('EcoRound Precision', 23), ('TitanCraft Pro-1', 17), ('SwiftSaw Precision', 16), ('SwiftDrill Precision', 23), ('PrecisionBlade X4', 22), ('MegaForce Turbo', 17)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - EcoDrive Elite: 22 instances
# - MegaRound Turbo: 12 instances
# - CircuMax Pro-3000: 15 instances
# - QuantumPro X1: 30 instances
# - TitanCraft Pro-1: 17 instances
# - EcoSaw Pro: 19 instances
# - MegaSaw Turbo: 14 instances
# - SwiftCircle Elite: 19 instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('EcoDrive Elite', 22), ('MegaRound Turbo', 12), ('CircuMax Pro-3000', 15), ('QuantumPro X1', 30), ('TitanCraft Pro-1', 17), ('EcoSaw Pro', 19), ('MegaSaw Turbo', 14), ('SwiftCircle Elite', 19)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - SwiftSaw Precision: 16 instances
# - CirclerPro X2: 28 instances
# - MegaCut TurboMax: 23 instances
# - GreenHarmony EcoPro: 21 instances
# - EcoRound Precision: 23 instances
# - SolarSprint 2000: 25 instances
# - TitanCut CircleMaster: 22 instances
# - GreenCut HarmonyPro: 17 instances
#
# These numbers reflect the available instances that are marked as available for use.
# [('SwiftSaw Precision', 16), ('CirclerPro X2', 28), ('MegaCut TurboMax', 23), ('GreenHarmony EcoPro', 21), ('EcoRound Precision', 23), ('SolarSprint 2000', 25), ('TitanCut CircleMaster', 22), ('GreenCut HarmonyPro', 17)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - **QuantumPro X1**: 30 available instances
# - **TitanBlade Max-3**: 19 available instances
# - **SolarSphere 3000**: 13 available instances
# - **TitanSaw Master-2**: 24 available instances
# - **MegaCut TurboMax**: 23 available instances
# - **EcoDrive Elite**: 22 available instances
# - **CirclerPro X2**: 28 available instances
# - **GreenCirc HarmonyPro**: 22 available instances
#
# These numbers reflect the current availability of each machine type.
# [('QuantumPro X1', 30), ('TitanBlade Max-3', 19), ('SolarSphere 3000', 13), ('TitanSaw Master-2', 24), ('MegaCut TurboMax', 23), ('EcoDrive Elite', 22), ('CirclerPro X2', 28), ('GreenCirc HarmonyPro', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - SolarSprint 2000: 25 available instances
# - PrecisionBlade X4: 22 available instances
# - TitanCraft Pro-1: 17 available instances
# - GreenHarmony EcoPro: 21 available instances
# - EcoRound Precision: 23 available instances
# - EcoBlade Elite: 14 available instances
# - SwiftSaw Precision: 16 available instances
# - EcoSaw Pro: 19 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('SolarSprint 2000', 25), ('PrecisionBlade X4', 22), ('TitanCraft Pro-1', 17), ('GreenHarmony EcoPro', 21), ('EcoRound Precision', 23), ('EcoBlade Elite', 14), ('SwiftSaw Precision', 16), ('EcoSaw Pro', 19)]
# Based on the information provided and the results from the query, it appears that there are a total of 154 instances available for use across the specified machine types: SwiftCut Precision, SwiftDrill Precision, SwiftSaw Precision, PrecisionBlade X4, EcoSaw Pro, TitanCut CircleMaster, MegaSaw Turbo, and TitanCraft Pro-1. However, the query response does not break down the number of instances by each machine type separately. Therefore, it's not possible to specify the exact number of available instances for each individual machine type from the provided data.
# [('SwiftCut Precision', 21), ('SwiftDrill Precision', 23), ('SwiftSaw Precision', 16), ('PrecisionBlade X4', 22), ('EcoSaw Pro', 19), ('TitanCut CircleMaster', 22), ('MegaSaw Turbo', 14), ('TitanCraft Pro-1', 17)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - SwiftCircle Elite: 19 available instances
# - SwiftDrill Precision: 23 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - EcoBlade Elite: 14 available instances
# - MegaCut TurboMax: 23 available instances
# - MegaRound Turbo: 12 available instances
# - PrecisionBlade X4: 22 available instances
# - GreenHarmony EcoPro: 21 available instances
# - SwiftSaw Precision: 16 available instances
#
# These numbers reflect the current availability of each machine type for use.
# [('SwiftCircle Elite', 19), ('SwiftDrill Precision', 23), ('GreenCirc HarmonyPro', 22), ('EcoBlade Elite', 14), ('MegaCut TurboMax', 23), ('MegaRound Turbo', 12), ('PrecisionBlade X4', 22), ('GreenHarmony EcoPro', 21), ('SwiftSaw Precision', 16)]
# Based on the information provided, here are the available instances for each specified machine type:
#
# - EcoRound Precision: 23 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - SolarBlade 4000: 20 available instances
# - SolarSphere 3000: 13 available instances
# - SwiftCut Precision: 21 available instances
# - SwiftDrill Precision: 23 available instances
# - SwiftSaw Precision: 16 available instances
# - TitanBlade Max-3: 19 available instances
# - TitanCut CircleMaster: 22 available instances
#
# These numbers represent the count of available instances for each machine type as per the latest query response.
# [('TitanCut CircleMaster', 22), ('SolarBlade 4000', 20), ('EcoRound Precision', 23), ('TitanBlade Max-3', 19), ('SolarSphere 3000', 13), ('SwiftCut Precision', 21), ('SwiftSaw Precision', 16), ('SwiftDrill Precision', 23), ('GreenCirc HarmonyPro', 22)]
# Based on the information provided, here are the available instances for each machine type:
#
# - GreenHarmony EcoPro: 21 available instances
# - TitanCraft Pro-1: 17 available instances
# - TitanSaw Master-2: 24 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - SwiftCut Precision: 21 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - SwiftSaw Precision: 16 available instances
# - SwiftDrill Precision: 23 available instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('GreenHarmony EcoPro', 21), ('TitanCraft Pro-1', 17), ('TitanSaw Master-2', 24), ('GreenCirc HarmonyPro', 22), ('SwiftCut Precision', 21), ('GreenCut HarmonyPro', 17), ('MegaCut TurboMax', 23), ('SwiftSaw Precision', 16), ('SwiftDrill Precision', 23)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - SwiftSaw Precision: 16 available instances
# - CircuMax Pro-3000: 15 available instances
# - EcoDrive Elite: 22 available instances
# - TitanCraft Pro-1: 17 available instances
# - CirclerPro X2: 28 available instances
# - GreenCut HarmonyPro: 17 available instances
# - GreenHarmony EcoPro: 21 available instances
# - PrecisionBlade X4: 22 available instances
# - SwiftCircle Elite: 19 available instances
#
# These numbers reflect the count of each machine type that is currently available for use.
# [('SwiftSaw Precision', 16), ('CircuMax Pro-3000', 15), ('EcoDrive Elite', 22), ('TitanCraft Pro-1', 17), ('CirclerPro X2', 28), ('GreenCut HarmonyPro', 17), ('GreenHarmony EcoPro', 21), ('PrecisionBlade X4', 22), ('SwiftCircle Elite', 19)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - CircuMax Pro-3000: 15 available instances
# - MegaSaw Turbo: 14 available instances
# - SwiftCircle Elite: 19 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - CirclerPro X2: 28 available instances
# - EcoRound Precision: 23 available instances
# - TitanCraft Pro-1: 17 available instances
# - TitanSaw Master-2: 24 available instances
#
# These numbers reflect the availability of each machine type for use.
# [('CircuMax Pro-3000', 15), ('MegaSaw Turbo', 14), ('SwiftCircle Elite', 19), ('GreenCut HarmonyPro', 17), ('MegaCut TurboMax', 23), ('CirclerPro X2', 28), ('EcoRound Precision', 23), ('TitanCraft Pro-1', 17), ('TitanSaw Master-2', 24)]
# Based on the information provided, here are the available machine instances for each specified machine type:
#
# - EcoSaw Pro: 19 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - QuantumPro X1: 30 available instances
# - MegaRound Turbo: 12 available instances
# - MegaCut TurboMax: 23 available instances
# - CircuMax Pro-3000: 15 available instances
# - EcoDrive Elite: 22 available instances
# - EcoRound Precision: 23 available instances
# - SolarSprint 2000: 25 available instances
#
# These numbers represent the quantity of each machine type that is currently available for use.
# [('EcoSaw Pro', 19), ('GreenCirc HarmonyPro', 22), ('QuantumPro X1', 30), ('MegaRound Turbo', 12), ('MegaCut TurboMax', 23), ('CircuMax Pro-3000', 15), ('EcoDrive Elite', 22), ('EcoRound Precision', 23), ('SolarSprint 2000', 25)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - SolarSphere 3000: 13 available instances
# - GreenCut HarmonyPro: 17 available instances
# - CirclerPro X2: 28 available instances
# - SwiftSaw Precision: 16 available instances
# - CircuMax Pro-3000: 15 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - MegaRound Turbo: 12 available instances
# - EcoSaw Pro: 19 available instances
# - TitanBlade Max-3: 19 available instances
#
# These numbers reflect the availability of each machine model for use.
# [('SolarSphere 3000', 13), ('GreenCut HarmonyPro', 17), ('CirclerPro X2', 28), ('SwiftSaw Precision', 16), ('CircuMax Pro-3000', 15), ('GreenCirc HarmonyPro', 22), ('MegaRound Turbo', 12), ('EcoSaw Pro', 19), ('TitanBlade Max-3', 19)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - CirclerPro X2: 28 available instances
# - EcoDrive Elite: 22 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - GreenHarmony EcoPro: 21 available instances
# - MegaCut TurboMax: 23 available instances
# - MegaSaw Turbo: 14 available instances
# - SolarBlade 4000: 20 available instances
# - SwiftCircle Elite: 19 available instances
# - TitanSaw Master-2: 24 available instances
#
# These numbers reflect the availability of each machine type for use.
# [('MegaSaw Turbo', 14), ('CirclerPro X2', 28), ('SwiftCircle Elite', 19), ('TitanSaw Master-2', 24), ('EcoDrive Elite', 22), ('SolarBlade 4000', 20), ('GreenHarmony EcoPro', 21), ('MegaCut TurboMax', 23), ('GreenCirc HarmonyPro', 22)]
# Based on the information provided, here are the numbers of available machine instances for each specified machine type:
#
# - MegaCut TurboMax: 23 available instances
# - SwiftSaw Precision: 16 available instances
# - SwiftCut Precision: 21 available instances
# - EcoRound Precision: 23 available instances
# - SolarSphere 3000: 13 available instances
# - GreenCut HarmonyPro: 17 available instances
# - TitanCut CircleMaster: 22 available instances
# - MegaRound Turbo: 12 available instances
# - SwiftCircle Elite: 19 available instances
#
# These numbers represent the count of each machine type that is available for use.
# [('MegaCut TurboMax', 23), ('SwiftSaw Precision', 16), ('SwiftCut Precision', 21), ('EcoRound Precision', 23), ('SolarSphere 3000', 13), ('GreenCut HarmonyPro', 17), ('TitanCut CircleMaster', 22), ('MegaRound Turbo', 12), ('SwiftCircle Elite', 19)]
# Based on the information provided, here are the available instances for each machine type:
#
# - GreenCut HarmonyPro: 17 instances
# - MegaForce Turbo: 17 instances
# - SolarBlade 4000: 20 instances
# - TitanCraft Pro-1: 17 instances
# - GreenHarmony EcoPro: 21 instances
# - TitanCut CircleMaster: 22 instances
# - SwiftDrill Precision: 23 instances
# - EcoSaw Pro: 19 instances
# - GreenCirc HarmonyPro: 22 instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('GreenCut HarmonyPro', 17), ('MegaForce Turbo', 17), ('SolarBlade 4000', 20), ('TitanCraft Pro-1', 17), ('GreenHarmony EcoPro', 21), ('TitanCut CircleMaster', 22), ('SwiftDrill Precision', 23), ('EcoSaw Pro', 19), ('GreenCirc HarmonyPro', 22)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - EcoSaw Pro: 19 available instances
# - CircuMax Pro-3000: 15 available instances
# - TitanCut CircleMaster: 22 available instances
# - EcoDrive Elite: 22 available instances
# - CirclerPro X2: 28 available instances
# - MegaSaw Turbo: 14 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - SolarBlade 4000: 20 available instances
# - MegaCut TurboMax: 23 available instances
# - TitanCraft Pro-1: 17 available instances
#
# These numbers reflect the availability of each machine type for use.
# [('EcoSaw Pro', 19), ('CircuMax Pro-3000', 15), ('TitanCut CircleMaster', 22), ('EcoDrive Elite', 22), ('CirclerPro X2', 28), ('MegaSaw Turbo', 14), ('GreenCirc HarmonyPro', 22), ('SolarBlade 4000', 20), ('MegaCut TurboMax', 23), ('TitanCraft Pro-1', 17)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - GreenCirc HarmonyPro: 22 available instances
# - MegaRound Turbo: 12 available instances
# - EcoDrive Elite: 22 available instances
# - TitanCut CircleMaster: 22 available instances
# - CirclerPro X2: 28 available instances
# - TitanBlade Max-3: 19 available instances
# - SwiftDrill Precision: 23 available instances
# - TitanCraft Pro-1: 17 available instances
# - SwiftSaw Precision: 16 available instances
# - MegaForce Turbo: 17 available instances
#
# These numbers reflect the available instances of each machine model that are marked as available for use.
# [('GreenCirc HarmonyPro', 22), ('MegaRound Turbo', 12), ('EcoDrive Elite', 22), ('TitanCut CircleMaster', 22), ('CirclerPro X2', 28), ('TitanBlade Max-3', 19), ('SwiftDrill Precision', 23), ('TitanCraft Pro-1', 17), ('SwiftSaw Precision', 16), ('MegaForce Turbo', 17)]
# Based on the information provided, here are the available instances for each specified machine type:
#
# - SolarBlade 4000: 20 available instances
# - GreenHarmony EcoPro: 21 available instances
# - CirclerPro X2: 28 available instances
# - EcoRound Precision: 23 available instances
# - EcoSaw Pro: 19 available instances
# - TitanSaw Master-2: 24 available instances
# - TitanBlade Max-3: 19 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - SolarSprint 2000: 25 available instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('SolarBlade 4000', 20), ('GreenHarmony EcoPro', 21), ('CirclerPro X2', 28), ('EcoRound Precision', 23), ('EcoSaw Pro', 19), ('TitanSaw Master-2', 24), ('TitanBlade Max-3', 19), ('GreenCut HarmonyPro', 17), ('MegaCut TurboMax', 23), ('SolarSprint 2000', 25)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - QuantumPro X1: 30 available instances
# - SwiftCut Precision: 21 available instances
# - PrecisionBlade X4: 22 available instances
# - TitanSaw Master-2: 24 available instances
# - TitanCraft Pro-1: 17 available instances
# - GreenHarmony EcoPro: 21 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - EcoBlade Elite: 14 available instances
# - CircuMax Pro-3000: 15 available instances
# - MegaCut TurboMax: 23 available instances
#
# These numbers reflect the available instances of each machine model that are marked as available for use.
# [('QuantumPro X1', 30), ('SwiftCut Precision', 21), ('PrecisionBlade X4', 22), ('TitanSaw Master-2', 24), ('TitanCraft Pro-1', 17), ('GreenHarmony EcoPro', 21), ('GreenCirc HarmonyPro', 22), ('EcoBlade Elite', 14), ('CircuMax Pro-3000', 15), ('MegaCut TurboMax', 23)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - GreenCirc HarmonyPro: 22 instances
# - SolarSprint 2000: 25 instances
# - TitanCut CircleMaster: 22 instances
# - MegaRound Turbo: 12 instances
# - GreenCut HarmonyPro: 17 instances
# - TitanBlade Max-3: 19 instances
# - SwiftCircle Elite: 19 instances
# - TitanSaw Master-2: 24 instances
# - QuantumPro X1: 30 instances
# - MegaSaw Turbo: 14 instances
#
# These numbers reflect the availability of each machine type as per the latest query response.
# [('GreenCirc HarmonyPro', 22), ('SolarSprint 2000', 25), ('TitanCut CircleMaster', 22), ('MegaRound Turbo', 12), ('GreenCut HarmonyPro', 17), ('TitanBlade Max-3', 19), ('SwiftCircle Elite', 19), ('TitanSaw Master-2', 24), ('QuantumPro X1', 30), ('MegaSaw Turbo', 14)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - SolarSphere 3000: 13 available instances
# - EcoRound Precision: 23 available instances
# - GreenCut HarmonyPro: 17 available instances
# - MegaCut TurboMax: 23 available instances
# - TitanSaw Master-2: 24 available instances
# - MegaRound Turbo: 12 available instances
# - SwiftSaw Precision: 16 available instances
# - MegaSaw Turbo: 14 available instances
# - GreenCirc HarmonyPro: 22 available instances
# - SwiftCut Precision: 21 available instances
#
# These numbers reflect the available instances of each machine type that are ready for use.
# [('SolarSphere 3000', 13), ('EcoRound Precision', 23), ('GreenCut HarmonyPro', 17), ('MegaCut TurboMax', 23), ('TitanSaw Master-2', 24), ('MegaRound Turbo', 12), ('SwiftSaw Precision', 16), ('MegaSaw Turbo', 14), ('GreenCirc HarmonyPro', 22), ('SwiftCut Precision', 21)]
# Based on the information provided, here are the numbers of available instances for each specified machine type:
#
# - TitanCut CircleMaster: 22 instances
# - MegaRound Turbo: 12 instances
# - TitanBlade Max-3: 19 instances
# - SwiftCut Precision: 21 instances
# - SolarSphere 3000: 13 instances
# - SwiftSaw Precision: 16 instances
# - GreenCirc HarmonyPro: 22 instances
# - SwiftDrill Precision: 23 instances
# - EcoBlade Elite: 14 instances
# - MegaCut TurboMax: 23 instances
#
# These numbers represent the quantity of each machine type that is available for use.
# [('TitanCut CircleMaster', 22), ('MegaRound Turbo', 12), ('TitanBlade Max-3', 19), ('SwiftCut Precision', 21), ('SolarSphere 3000', 13), ('SwiftSaw Precision', 16), ('GreenCirc HarmonyPro', 22), ('SwiftDrill Precision', 23), ('EcoBlade Elite', 14), ('MegaCut TurboMax', 23)]
# Based on the available information, here are the numbers of available instances for each specified machine type:
#
# - CirclerPro X2: 28 instances
# - GreenCut HarmonyPro: 17 instances
# - SwiftDrill Precision: 23 instances
# - TitanSaw Master-2: 24 instances
# - EcoRound Precision: 23 instances
# - MegaSaw Turbo: 14 instances
# - SolarSprint 2000: 25 instances
# - EcoSaw Pro: 19 instances
# - TitanBlade Max-3: 19 instances
# - MegaRound Turbo: 12 instances
#
# These numbers represent the count of available instances for each machine model as specified.
# [('CirclerPro X2', 28), ('GreenCut HarmonyPro', 17), ('SwiftDrill Precision', 23), ('TitanSaw Master-2', 24), ('EcoRound Precision', 23), ('MegaSaw Turbo', 14), ('SolarSprint 2000', 25), ('EcoSaw Pro', 19), ('TitanBlade Max-3', 19), ('MegaRound Turbo', 12)]
# Based on the available information, here are the numbers of available instances for each specified machine model:
#
# - SolarSphere 3000: 13 available instances
# - TitanCraft Pro-1: 17 available instances
# - GreenHarmony EcoPro: 21 available instances
# - SolarBlade 4000: 20 available instances
# - SwiftCircle Elite: 19 available instances
# - EcoSaw Pro: 19 available instances
# - MegaCut TurboMax: 23 available instances
# - EcoRound Precision: 23 available instances
# - TitanBlade Max-3: 19 available instances
# - EcoDrive Elite: 22 available instances
#
# These numbers reflect the count of each machine model that is marked as available for use.
# [('SolarSphere 3000', 13), ('TitanCraft Pro-1', 17), ('GreenHarmony EcoPro', 21), ('SolarBlade 4000', 20), ('SwiftCircle Elite', 19), ('EcoSaw Pro', 19), ('MegaCut TurboMax', 23), ('EcoRound Precision', 23), ('TitanBlade Max-3', 19), ('EcoDrive Elite', 22)]
# Based on the information provided, here are the numbers of available instances for each specified machine model:
#
# - TitanCut CircleMaster: 22 available instances
# - TitanBlade Max-3: 19 available instances
# - EcoSaw Pro: 19 available instances
# - SolarSphere 3000: 13 available instances
# - SwiftCut Precision: 21 available instances
# - GreenCut HarmonyPro: 17 available instances
# - EcoRound Precision: 23 available instances
# - MegaRound Turbo: 12 available instances
# - SolarSprint 2000: 25 available instances
# - CirclerPro X2: 28 available instances
#
# These numbers reflect the count of available instances for each machine model, indicating how many units of each are currently available for use.
# [('TitanCut CircleMaster', 22), ('TitanBlade Max-3', 19), ('EcoSaw Pro', 19), ('SolarSphere 3000', 13), ('SwiftCut Precision', 21), ('GreenCut HarmonyPro', 17), ('EcoRound Precision', 23), ('MegaRound Turbo', 12), ('SolarSprint 2000', 25), ('CirclerPro X2', 28)]
